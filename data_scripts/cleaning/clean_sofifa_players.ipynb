# %%
import pandas as pd
import glob
import os

# %%
### if '+' present, add numbers, if '-' present, subtract numbers

def safe_eval(x):
    try:
        if '+' in str(x):
            return sum(int(i) for i in str(x).split('+'))
        elif '-' in str(x):
            return int(str(x).split('-')[0]) - sum(int(i) for i in str(x).split('-')[1:])
        else:
            return int(x)
    except:
        return x

# %%
def clean_player(ex):
    ex = ex.copy()
    
    ex = ex.loc[:, ~ex.columns.str.contains('^Unnamed')]
    
    ex.loc[:, 'Name'] = ex['Name'].str.replace(r'[A-Z]+$', '', regex=True)
    ex.loc[:, 'date'] = pd.to_datetime(ex['date']).dt.date
    
    pat = r'(\w+)\((\d+)\)(\d{4}) ~ (\d{4})'
    ex[['position', 'jersey_num', 'contract_start',
        'contract_end']] = ex.loc[:, 'Team & Contract'].astype(str).str.extract(pat)

    ex.loc[:, 'height_cm'] = ex['Height'].astype(str).str.split('cm / ').str[0].astype('Int64')
    ex.loc[:, 'weight_kg'] = ex['Weight'].astype(str).str.split('kg / ').str[0].astype('Int64')

    ex.loc[:, 'wage_eur'] = ex['Wage'].astype(str).str.replace('€', '').str.replace(
        ',', '').str.replace('K', '000').str.replace('M',
                                                     '000000').astype('Int64')

    ex.loc[:, 'value_eur'] = ex['Value'].astype(str).str.replace('€', '').str.replace(
        ',', '').str.replace('.', '').str.replace('K', '000').str.replace(
            'M', '000000').astype('Int64')
    
    
    ex.drop(columns=['Height', 'Weight', 'Team & Contract', 'Value', 'Wage'],
            inplace=True)
    
    ## safe eval everything but date
    for col in ex.columns:
        if col != 'date':
            ex[col] = ex[col].apply(safe_eval)

    
    main_cols = [
        'ID', 'date', 'Name', 'Age', 'height_cm', 'weight_kg', 'team',
        'contract_start', 'contract_end', 'position', 'foot', 'jersey_num',
        'wage_eur', 'value_eur'
    ]
    
    rest_cols = [col for col in ex.columns if col not in main_cols]
    ex = ex[main_cols + rest_cols]
    
    for c in ex.columns:
        try:
            ex[c] = pd.to_numeric(ex[c])
        except (ValueError, TypeError):
            pass 
    
    ex.columns = ex.columns.str.lower().str.replace(' ', '_')
    
    return ex

# %%
csv = pd.read_csv('G:\\My Drive\\GitHubProjects\\MLS\\data\\scraping\\players\\Atlanta-United-Apr-1,-2025.csv')

clean_csv = clean_player(csv)

clean_csv
# Out:
#         id        date           name  age  height_cm  weight_kg  \
# 0   164505  2025-04-01       B. Guzan   39        193         94
# 1   237662  2025-04-01      B. Lennon   26        177         70
# 2   216730  2025-04-01   S. Gregersen   29        192         83
# 3   203398  2025-04-01    D. Williams   31        180         75
# 4   256044  2025-04-01   Pedro Amador   25        181         73
# 5   243222  2025-04-01       B. Slisz   25        180         76
# 6   192955  2025-04-01       M. Klich   34        183         84
# 7   214092  2025-04-01   A. Miranchuk   28        182         74
# 8   230977  2025-04-01     M. Almirón   30        174         70
# 9   237295  2025-04-01  E. Latte Lath   25        176         72
# 10  239755  2025-04-01  S. Lobjanidze   29        175         72
# 11  228768  2025-04-01    Xande Silva   27        177         68
# 12  248555  2025-04-01    E. Mosquera   23        172         58
# 13  235885  2025-04-01     T. Muyumba   27        165         60
# 14  234178  2025-04-01       L. Abram   28        181         78
# 15  240921  2025-04-01   R. Hernández   26        170         70
# 16  274272  2025-04-01        N. Cobb   18        185         75
# 17  279705  2025-04-01       J. Cohen   31        186         79
# 18  274273  2025-04-01     A. Fortune   21        175         75
# 19  212790  2025-04-01      J. Thiaré   31        180         68
# 20  259934  2025-04-01     E. Morales   20        190         77
# 21  278490  2025-04-01     L. Brennan   19        180         68
# 22   76454  2025-04-01      W. Reilly   21        178         73
# 23  232785  2025-04-01     C. Togashi   30        178         75
# 24   70112  2025-04-01      A. Torres   16        172         70
# 25   74622  2025-04-01     M. Edwards   21        178         79
# 26   76453  2025-04-01      A. Gordon   17        170         65
#
#               team  contract_start  contract_end position  ...  \
# 0   Atlanta United            2017          2025       GK  ...
# 1   Atlanta United            2019          2025       RB  ...
# 2   Atlanta United            2024          2027      RCB  ...
# 3   Atlanta United            2024          2025      LCB  ...
# 4   Atlanta United            2024          2026       LB  ...
# 5   Atlanta United            2024          2028      RCM  ...
# 6   Atlanta United            2024          2025      LCM  ...
# 7   Atlanta United            2024          2028      CAM  ...
# 8   Atlanta United            2025          2028       RW  ...
# 9   Atlanta United            2025          2029       ST  ...
# 10  Atlanta United            2023          2026       LW  ...
# 11  Atlanta United            2023          2026      SUB  ...
# 12  Atlanta United            2022          2026      SUB  ...
# 13  Atlanta United            2023          2027      SUB  ...
# 14  Atlanta United            2023          2026      SUB  ...
# 15  Atlanta United            2022          2025      SUB  ...
# 16  Atlanta United            2023          2026      SUB  ...
# 17  Atlanta United            2023          2025      SUB  ...
# 18  Atlanta United            2023          2026      SUB  ...
# 19  Atlanta United            2023          2025      SUB  ...
# 20  Atlanta United            2024          2025      SUB  ...
# 21  Atlanta United            2024          2027      SUB  ...
# 22  Atlanta United            2025          2028      SUB  ...
# 23  Atlanta United            2025          2025      RES  ...
# 24  Atlanta United            2024          2028      RES  ...
# 25  Atlanta United            2024          2025      RES  ...
# 26  Atlanta United            2025          2026      RES  ...
#
#    total_defending  defensive_awareness  standing_tackle  sliding_tackle  \
# 0               41                   12               15              14
# 1              191                   63               65              63
# 2              209                   68               71              70
# 3              200                   67               66              67
# 4              199                   64               68              67
# 5              198                   66               67              65
# 6              198                   66               69              63
# 7               79                   22               28              29
# 8              169                   61               59              49
# 9              113                   27               41              45
# 10             128                   43               42              43
# 11              70                   25               23              22
# 12              45                   17               10              18
# 13             195                   64               67              64
# 14             199                   67               66              66
# 15             187                   63               63              61
# 16             197                   63               69              65
# 17              27                    5               11              11
# 18             146                   34               55              57
# 19              58                   20               20              18
# 20             189                   62               65              62
# 21             151                   40               56              55
# 22             142                   43               48              51
# 23              85                   34               31              20
# 24             139                   45               49              45
# 25             165                   51               60              54
# 26              72                   23               26              23
#
#     total_goalkeeping  gk_diving gk_handling  gk_kicking  gk_positioning  \
# 0                 340         69          68          65              69
# 1                  37          6           6          10               8
# 2                  47          8          10          10               7
# 3                  42          7           9           6              10
# 4                  48          8          10          11              12
# 5                  44         14           5          12               8
# 6                  64         11          16          12              11
# 7                  52          8           8           9              12
# 8                  53          6           9          13              13
# 9                  34          7           9           5               8
# 10                 52         12           6          10              11
# 11                 65          8          16          15              15
# 12                 40          9           9           5              10
# 13                 43          6          11           6               6
# 14                 50         10           9          13               6
# 15                 45          8          13           6              12
# 16                 50         12           6          10              10
# 17                332         67          66          65              68
# 18                 44          8           5           9              12
# 19                 44          7          14           6               8
# 20                 54         11          11           5              13
# 21                 56         12          12          12               9
# 22                 50         10          13          10              10
# 23                 57          7          12          14              12
# 24                 47          8          14           8              12
# 25                 51         10           9          11              13
# 26                 54         11           9           9              12
#
#     gk_reflexes
# 0            69
# 1             7
# 2            12
# 3            10
# 4             7
# 5             5
# 6            14
# 7            15
# 8            12
# 9             5
# 10           13
# 11           11
# 12            7
# 13           14
# 14           12
# 15            6
# 16           12
# 17           66
# 18           10
# 19            9
# 20           14
# 21           11
# 22            7
# 23           12
# 24            5
# 25            8
# 26           13
#
# [27 rows x 57 columns]

# %%
files = glob.glob('data/scraping/players/*.csv')

# %%
for file in glob.glob('G:/My Drive/GitHubProjects/MLS/data/scraping/players/*.csv'):
    df = pd.read_csv(file)
    cleaned_df = clean_player(df)
    filename = os.path.basename(file)
    cleaned_df.to_csv(
        f"G:/My Drive/GitHubProjects/MLS/data/data_clean/players/cleaned_{filename}.csv",
        index=False)
