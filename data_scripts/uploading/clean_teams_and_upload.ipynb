# %%
from pathlib import Path
import pandas as pd
import re
from sqlalchemy import create_engine

# %%
INPUT_DIR = Path(r"G:\My Drive\GitHubProjects\MLS\data\scraping\teams")   # folder with CSVs
OUTPUT_FILE = Path(r"G:\My Drive\GitHubProjects\MLS\data\scraping\teams\teams_master.csv")

# %%
ID_MAP = {
    687: "Columbus Crew",
    688: "DC United",
    689: "New York Red Bulls",
    691: "New England Revolution",
    693: "Chicago Fire",
    694: "Colorado Rapids",
    695: "FC Dallas",
    696: "Sporting Kansas City",
    697: "LA Galaxy",
    698: "Houston Dynamo",
    101112: "Vancouver Whitecaps FC",
    111065: "Real Salt Lake",
    111138: "Minnesota United FC",
    111139: "CF Montréal",
    111140: "Portland Timbers",
    111144: "Seattle Sounders FC",
    111651: "Toronto FC",
    111928: "San Jose Earthquakes",
    112134: "Philadelphia Union",
    112606: "Orlando City SC",
    112828: "New York City FC",
    112885: "Atlanta United",
    112893: "Inter Miami",
    112996: "Los Angeles FC",
    113018: "St. Louis CITY SC",
    113149: "FC Cincinnati",
    114161: "Austin FC",
    114162: "Nashville SC",
    114640: "Charlotte FC",
    131439: "San Diego FC",
}


def parse_date_from_filename(fname: str) -> pd.Timestamp:
    """Extract date from filename like teams_Jan 2, 2015.csv"""
    m = re.search(r"teams_(.+)\.csv", fname, re.IGNORECASE)
    if not m:
        raise ValueError(f"Cannot extract date from {fname}")
    return pd.to_datetime(m.group(1), format="%b %d, %Y")

# %%
def to_snake_case(col: str) -> str:
    col = re.sub(r"[^\w]+", "_", col)
    col = re.sub(r"_+", "_", col)
    return col.strip("_").lower()

# %%
def split_formation(series: pd.Series) -> tuple[pd.Series, pd.Series]:
    """Split strings like '4-2-3-1 Wide' -> base='4-2-3-1', style='wide'"""
    s = series.astype(str).str.strip()
    m = s.str.extract(r"^\s*(?P<base>\d(?:-\d)+)\s*(?P<style>.*)$")
    base = m["base"].str.lower()
    style = m["style"].str.strip().str.lower().replace({"": pd.NA})
    return base, style

# %%
def clean_file(path: Path) -> pd.DataFrame:
    df = pd.read_csv(path)

    # Drop first and last columns
    if df.shape[1] >= 2:
        df = df.drop([df.columns[0], df.columns[-1]], axis=1)

    # Replace Name using ID
    if "ID" in df.columns and "Name" in df.columns:
        df["Name"] = df["ID"].map(ID_MAP).fillna(df["Name"])

    # Split Formation into base + style
    formation_col = "Formation" if "Formation" in df.columns else ("formation" if "formation" in df.columns else None)
    if formation_col:
        base, style = split_formation(df[formation_col])
        insert_at = list(df.columns).index(formation_col)
        df.insert(insert_at, "formation_base", base)
        df.insert(insert_at + 1, "formation_style", style)
        df = df.drop(columns=[formation_col])

    # Add date
    df.insert(0, "date", parse_date_from_filename(path.name))

    # Rename columns to lowercase snake_case
    df.columns = [to_snake_case(c) for c in df.columns]

    return df

# %%
def main():
    files = sorted(INPUT_DIR.glob("teams_*.csv"))
    if not files:
        print("No CSVs found. Check your folder or naming.")
        return

    frames = []
    for f in files:
        try:
            frames.append(clean_file(f))
            print(f"[ok] {f.name}")
        except Exception as e:
            print(f"[skip] {f.name}: {e}")

    if not frames:
        print("Nothing to combine.")
        return

    master = pd.concat(frames, ignore_index=True)
    master.to_csv(OUTPUT_FILE, index=False)
    print(f"\nMaster CSV created: {OUTPUT_FILE}")

# %%
if __name__ == "__main__":
    main()
# Out:
# [ok] teams_Apr 1, 2015.csv
# [ok] teams_Apr 1, 2019.csv
# [ok] teams_Apr 1, 2025.csv
# [ok] teams_Apr 10, 2015.csv
# [ok] teams_Apr 10, 2017.csv
# [ok] teams_Apr 10, 2020.csv
# [ok] teams_Apr 11, 2019.csv
# [ok] teams_Apr 12, 2018.csv
# [ok] teams_Apr 12, 2021.csv
# [ok] teams_Apr 12, 2023.csv
# [ok] teams_Apr 13, 2017.csv
# [ok] teams_Apr 13, 2021.csv
# [ok] teams_Apr 13, 2022.csv
# [ok] teams_Apr 14, 2016.csv
# [ok] teams_Apr 14, 2023.csv
# [ok] teams_Apr 15, 2019.csv
# [ok] teams_Apr 15, 2020.csv
# [ok] teams_Apr 16, 2018.csv
# [ok] teams_Apr 16, 2019.csv
# [ok] teams_Apr 16, 2021.csv
# [ok] teams_Apr 16, 2025.csv
# [ok] teams_Apr 17, 2015.csv
# [ok] teams_Apr 17, 2023.csv
# [ok] teams_Apr 18, 2017.csv
# [ok] teams_Apr 18, 2019.csv
# [ok] teams_Apr 19, 2018.csv
# [ok] teams_Apr 2, 2020.csv
# [ok] teams_Apr 20, 2017.csv
# [ok] teams_Apr 20, 2021.csv
# [ok] teams_Apr 21, 2016.csv
# [ok] teams_Apr 21, 2022.csv
# [ok] teams_Apr 21, 2023.csv
# [ok] teams_Apr 22, 2020.csv
# [ok] teams_Apr 22, 2025.csv
# [ok] teams_Apr 23, 2018.csv
# [ok] teams_Apr 23, 2019.csv
# [ok] teams_Apr 23, 2021.csv
# [ok] teams_Apr 23, 2024.csv
# [ok] teams_Apr 24, 2015.csv
# [ok] teams_Apr 24, 2017.csv
# [ok] teams_Apr 25, 2019.csv
# [ok] teams_Apr 25, 2023.csv
# [ok] teams_Apr 26, 2018.csv
# [ok] teams_Apr 26, 2022.csv
# [ok] teams_Apr 27, 2017.csv
# [ok] teams_Apr 27, 2023.csv
# [ok] teams_Apr 28, 2016.csv
# [ok] teams_Apr 28, 2020.csv
# [ok] teams_Apr 29, 2019.csv
# [ok] teams_Apr 29, 2020.csv
# [ok] teams_Apr 3, 2017.csv
# [ok] teams_Apr 3, 2018.csv
# [ok] teams_Apr 30, 2018.csv
# [ok] teams_Apr 4, 2019.csv
# [ok] teams_Apr 5, 2018.csv
# [ok] teams_Apr 5, 2023.csv
# [ok] teams_Apr 6, 2017.csv
# [ok] teams_Apr 6, 2023.csv
# [ok] teams_Apr 7, 2016.csv
# [ok] teams_Apr 7, 2020.csv
# [ok] teams_Apr 8, 2019.csv
# [ok] teams_Apr 8, 2025.csv
# [ok] teams_Apr 9, 2018.csv
# [ok] teams_Apr 9, 2024.csv
# [ok] teams_Aug 1, 2023.csv
# [ok] teams_Aug 10, 2017.csv
# [ok] teams_Aug 11, 2016.csv
# [ok] teams_Aug 11, 2023.csv
# [ok] teams_Aug 12, 2020.csv
# [ok] teams_Aug 14, 2015.csv
# [ok] teams_Aug 14, 2017.csv
# [ok] teams_Aug 15, 2019.csv
# [ok] teams_Aug 15, 2022.csv
# [ok] teams_Aug 16, 2021.csv
# [ok] teams_Aug 16, 2023.csv
# [ok] teams_Aug 17, 2017.csv
# [ok] teams_Aug 18, 2016.csv
# [ok] teams_Aug 18, 2022.csv
# [ok] teams_Aug 20, 2019.csv
# [ok] teams_Aug 20, 2020.csv
# [ok] teams_Aug 20, 2024.csv
# [ok] teams_Aug 21, 2018.csv
# [ok] teams_Aug 22, 2017.csv
# [ok] teams_Aug 23, 2018.csv
# [ok] teams_Aug 24, 2017.csv
# [ok] teams_Aug 24, 2020.csv
# [ok] teams_Aug 24, 2023.csv
# [ok] teams_Aug 25, 2016.csv
# [ok] teams_Aug 26, 2016.csv
# [ok] teams_Aug 27, 2015.csv
# [ok] teams_Aug 27, 2021.csv
# [ok] teams_Aug 28, 2015.csv
# [ok] teams_Aug 28, 2017.csv
# [ok] teams_Aug 29, 2019.csv
# [ok] teams_Aug 3, 2017.csv
# [ok] teams_Aug 3, 2018.csv
# [ok] teams_Aug 3, 2023.csv
# [ok] teams_Aug 30, 2018.csv
# [ok] teams_Aug 30, 2021.csv
# [ok] teams_Aug 31, 2017.csv
# [ok] teams_Aug 4, 2016.csv
# [ok] teams_Aug 4, 2021.csv
# [ok] teams_Aug 6, 2020.csv
# [ok] teams_Aug 6, 2021.csv
# [ok] teams_Aug 7, 2015.csv
# [ok] teams_Aug 7, 2024.csv
# [ok] teams_Aug 9, 2022.csv
# [ok] teams_Dec 1, 2016.csv
# [ok] teams_Dec 1, 2021.csv
# [ok] teams_Dec 10, 2015.csv
# [ok] teams_Dec 10, 2020.csv
# [ok] teams_Dec 11, 2017.csv
# [ok] teams_Dec 11, 2019.csv
# [ok] teams_Dec 11, 2020.csv
# [ok] teams_Dec 11, 2023.csv
# [ok] teams_Dec 11, 2024.csv
# [ok] teams_Dec 12, 2014.csv
# [ok] teams_Dec 12, 2016.csv
# [ok] teams_Dec 13, 2018.csv
# [ok] teams_Dec 13, 2021.csv
# [ok] teams_Dec 14, 2017.csv
# [ok] teams_Dec 14, 2019.csv
# [ok] teams_Dec 15, 2016.csv
# [ok] teams_Dec 16, 2021.csv
# [ok] teams_Dec 17, 2015.csv
# [ok] teams_Dec 17, 2018.csv
# [ok] teams_Dec 17, 2022.csv
# [ok] teams_Dec 18, 2017.csv
# [ok] teams_Dec 18, 2019.csv
# [ok] teams_Dec 18, 2023.csv
# [ok] teams_Dec 18, 2024.csv
# [ok] teams_Dec 19, 2014.csv
# [ok] teams_Dec 19, 2016.csv
# [ok] teams_Dec 20, 2018.csv
# [ok] teams_Dec 20, 2021.csv
# [ok] teams_Dec 21, 2017.csv
# [ok] teams_Dec 22, 2016.csv
# [ok] teams_Dec 24, 2015.csv
# [ok] teams_Dec 24, 2019.csv
# [ok] teams_Dec 27, 2014.csv
# [ok] teams_Dec 27, 2016.csv
# [ok] teams_Dec 27, 2018.csv
# [ok] teams_Dec 28, 2017.csv
# [ok] teams_Dec 3, 2015.csv
# [ok] teams_Dec 3, 2018.csv
# [ok] teams_Dec 3, 2021.csv
# [ok] teams_Dec 30, 2015.csv
# [ok] teams_Dec 4, 2017.csv
# [ok] teams_Dec 4, 2019.csv
# [ok] teams_Dec 4, 2020.csv
# [ok] teams_Dec 5, 2016.csv
# [ok] teams_Dec 5, 2024.csv
# [ok] teams_Dec 6, 2019.csv
# [ok] teams_Dec 6, 2022.csv
# [ok] teams_Dec 6, 2023.csv
# [ok] teams_Dec 7, 2017.csv
# [ok] teams_Dec 7, 2021.csv
# [ok] teams_Dec 8, 2016.csv
# [ok] teams_Dec 9, 2021.csv
# [ok] teams_Feb 1, 2018.csv
# [ok] teams_Feb 1, 2020.csv
# [ok] teams_Feb 1, 2022.csv
# [ok] teams_Feb 1, 2024.csv
# [ok] teams_Feb 10, 2022.csv
# [ok] teams_Feb 11, 2016.csv
# [ok] teams_Feb 11, 2019.csv
# [ok] teams_Feb 12, 2018.csv
# [ok] teams_Feb 13, 2015.csv
# [ok] teams_Feb 13, 2016.csv
# [ok] teams_Feb 13, 2020.csv
# [ok] teams_Feb 13, 2023.csv
# [ok] teams_Feb 14, 2017.csv
# [ok] teams_Feb 14, 2019.csv
# [ok] teams_Feb 14, 2022.csv
# [ok] teams_Feb 14, 2025.csv
# [ok] teams_Feb 15, 2018.csv
# [ok] teams_Feb 15, 2024.csv
# [ok] teams_Feb 16, 2017.csv
# [ok] teams_Feb 18, 2016.csv
# [ok] teams_Feb 18, 2021.csv
# [ok] teams_Feb 18, 2022.csv
# [ok] teams_Feb 19, 2016.csv
# [ok] teams_Feb 19, 2018.csv
# [ok] teams_Feb 19, 2021.csv
# [ok] teams_Feb 19, 2025.csv
# [ok] teams_Feb 2, 2017.csv
# [ok] teams_Feb 20, 2015.csv
# [ok] teams_Feb 20, 2017.csv
# [ok] teams_Feb 21, 2019.csv
# [ok] teams_Feb 22, 2017.csv
# [ok] teams_Feb 22, 2018.csv
# [ok] teams_Feb 22, 2019.csv
# [ok] teams_Feb 22, 2022.csv
# [ok] teams_Feb 22, 2023.csv
# [ok] teams_Feb 22, 2024.csv
# [ok] teams_Feb 23, 2023.csv
# [ok] teams_Feb 24, 2020.csv
# [ok] teams_Feb 24, 2025.csv
# [ok] teams_Feb 25, 2016.csv
# [ok] teams_Feb 26, 2018.csv
# [ok] teams_Feb 27, 2015.csv
# [ok] teams_Feb 27, 2017.csv
# [ok] teams_Feb 28, 2019.csv
# [ok] teams_Feb 28, 2023.csv
# [ok] teams_Feb 3, 2022.csv
# [ok] teams_Feb 4, 2016.csv
# [ok] teams_Feb 4, 2019.csv
# [ok] teams_Feb 4, 2025.csv
# [ok] teams_Feb 5, 2018.csv
# [ok] teams_Feb 5, 2021.csv
# [ok] teams_Feb 5, 2025.csv
# [ok] teams_Feb 6, 2015.csv
# [ok] teams_Feb 6, 2017.csv
# [ok] teams_Feb 7, 2019.csv
# [ok] teams_Feb 7, 2020.csv
# [ok] teams_Feb 7, 2022.csv
# [ok] teams_Feb 7, 2023.csv
# [ok] teams_Feb 8, 2018.csv
# [ok] teams_Feb 8, 2024.csv
# [ok] teams_Feb 9, 2017.csv
# [ok] teams_Jan 10, 2019.csv
# [ok] teams_Jan 10, 2020.csv
# [ok] teams_Jan 11, 2018.csv
# [ok] teams_Jan 11, 2021.csv
# [ok] teams_Jan 11, 2022.csv
# [ok] teams_Jan 12, 2017.csv
# [ok] teams_Jan 13, 2022.csv
# [ok] teams_Jan 13, 2023.csv
# [ok] teams_Jan 14, 2016.csv
# [ok] teams_Jan 14, 2019.csv
# [ok] teams_Jan 15, 2018.csv
# [ok] teams_Jan 15, 2021.csv
# [ok] teams_Jan 16, 2015.csv
# [ok] teams_Jan 16, 2017.csv
# [ok] teams_Jan 16, 2025.csv
# [ok] teams_Jan 17, 2017.csv
# [ok] teams_Jan 17, 2019.csv
# [ok] teams_Jan 17, 2024.csv
# [ok] teams_Jan 18, 2018.csv
# [ok] teams_Jan 18, 2022.csv
# [ok] teams_Jan 18, 2023.csv
# [ok] teams_Jan 19, 2017.csv
# [ok] teams_Jan 19, 2021.csv
# [ok] teams_Jan 2, 2015.csv
# [ok] teams_Jan 2, 2018.csv
# [ok] teams_Jan 2, 2020.csv
# [ok] teams_Jan 21, 2016.csv
# [ok] teams_Jan 21, 2019.csv
# [ok] teams_Jan 21, 2022.csv
# [ok] teams_Jan 22, 2018.csv
# [ok] teams_Jan 22, 2020.csv
# [ok] teams_Jan 22, 2021.csv
# [ok] teams_Jan 23, 2015.csv
# [ok] teams_Jan 23, 2017.csv
# [ok] teams_Jan 23, 2025.csv
# [ok] teams_Jan 24, 2019.csv
# [ok] teams_Jan 24, 2020.csv
# [ok] teams_Jan 24, 2022.csv
# [ok] teams_Jan 25, 2018.csv
# [ok] teams_Jan 25, 2023.csv
# [ok] teams_Jan 26, 2015.csv
# [ok] teams_Jan 26, 2017.csv
# [ok] teams_Jan 26, 2021.csv
# [ok] teams_Jan 27, 2022.csv
# [ok] teams_Jan 28, 2015.csv
# [ok] teams_Jan 28, 2016.csv
# [ok] teams_Jan 28, 2019.csv
# [ok] teams_Jan 29, 2018.csv
# [ok] teams_Jan 29, 2021.csv
# [ok] teams_Jan 3, 2017.csv
# [ok] teams_Jan 3, 2019.csv
# [ok] teams_Jan 30, 2015.csv
# [ok] teams_Jan 30, 2017.csv
# [ok] teams_Jan 30, 2023.csv
# [ok] teams_Jan 30, 2024.csv
# [ok] teams_Jan 31, 2019.csv
# [ok] teams_Jan 31, 2024.csv
# [ok] teams_Jan 4, 2018.csv
# [ok] teams_Jan 5, 2017.csv
# [ok] teams_Jan 6, 2020.csv
# [ok] teams_Jan 6, 2021.csv
# [ok] teams_Jan 7, 2016.csv
# [ok] teams_Jan 7, 2019.csv
# [ok] teams_Jan 8, 2018.csv
# [ok] teams_Jan 9, 2015.csv
# [ok] teams_Jan 9, 2017.csv
# [ok] teams_Jan 9, 2025.csv
# [ok] teams_Jul 10, 2015.csv
# [ok] teams_Jul 10, 2017.csv
# [ok] teams_Jul 10, 2023.csv
# [ok] teams_Jul 11, 2019.csv
# [ok] teams_Jul 12, 2021.csv
# [ok] teams_Jul 12, 2022.csv
# [ok] teams_Jul 13, 2017.csv
# [ok] teams_Jul 13, 2023.csv
# [ok] teams_Jul 14, 2016.csv
# [ok] teams_Jul 15, 2021.csv
# [ok] teams_Jul 16, 2015.csv
# [ok] teams_Jul 16, 2020.csv
# [ok] teams_Jul 17, 2017.csv
# [ok] teams_Jul 17, 2023.csv
# [ok] teams_Jul 17, 2025.csv
# [ok] teams_Jul 18, 2019.csv
# [ok] teams_Jul 18, 2022.csv
# [ok] teams_Jul 19, 2018.csv
# [ok] teams_Jul 19, 2021.csv
# [ok] teams_Jul 2, 2020.csv
# [ok] teams_Jul 20, 2017.csv
# [ok] teams_Jul 20, 2023.csv
# [ok] teams_Jul 21, 2016.csv
# [ok] teams_Jul 21, 2022.csv
# [ok] teams_Jul 23, 2020.csv
# [ok] teams_Jul 23, 2021.csv
# [ok] teams_Jul 24, 2015.csv
# [ok] teams_Jul 24, 2017.csv
# [ok] teams_Jul 24, 2023.csv
# [ok] teams_Jul 24, 2024.csv
# [ok] teams_Jul 26, 2018.csv
# [ok] teams_Jul 26, 2022.csv
# [ok] teams_Jul 27, 2017.csv
# [ok] teams_Jul 27, 2021.csv
# [ok] teams_Jul 28, 2016.csv
# [ok] teams_Jul 3, 2015.csv
# [ok] teams_Jul 3, 2017.csv
# [ok] teams_Jul 30, 2020.csv
# [ok] teams_Jul 30, 2021.csv
# [ok] teams_Jul 31, 2015.csv
# [ok] teams_Jul 31, 2017.csv
# [ok] teams_Jul 4, 2019.csv
# [ok] teams_Jul 4, 2024.csv
# [ok] teams_Jul 4, 2025.csv
# [ok] teams_Jul 5, 2021.csv
# [ok] teams_Jul 5, 2023.csv
# [ok] teams_Jul 6, 2017.csv
# [ok] teams_Jul 6, 2022.csv
# [ok] teams_Jul 7, 2016.csv
# [ok] teams_Jul 7, 2021.csv
# [ok] teams_Jul 7, 2022.csv
# [ok] teams_Jul 8, 2020.csv
# [ok] teams_Jul 8, 2024.csv
# [ok] teams_Jul 9, 2021.csv
# [ok] teams_Jul 9, 2025.csv
# [ok] teams_Jun 1, 2017.csv
# [ok] teams_Jun 1, 2022.csv
# [ok] teams_Jun 11, 2018.csv
# [ok] teams_Jun 11, 2020.csv
# [ok] teams_Jun 11, 2021.csv
# [ok] teams_Jun 11, 2024.csv
# [ok] teams_Jun 12, 2015.csv
# [ok] teams_Jun 12, 2017.csv
# [ok] teams_Jun 12, 2023.csv
# [ok] teams_Jun 12, 2024.csv
# [ok] teams_Jun 13, 2019.csv
# [ok] teams_Jun 13, 2022.csv
# [ok] teams_Jun 14, 2017.csv
# [ok] teams_Jun 14, 2018.csv
# [ok] teams_Jun 15, 2021.csv
# [ok] teams_Jun 16, 2016.csv
# [ok] teams_Jun 16, 2022.csv
# [ok] teams_Jun 17, 2020.csv
# [ok] teams_Jun 18, 2021.csv
# [ok] teams_Jun 19, 2015.csv
# [ok] teams_Jun 19, 2017.csv
# [ok] teams_Jun 19, 2023.csv
# [ok] teams_Jun 19, 2025.csv
# [ok] teams_Jun 2, 2016.csv
# [ok] teams_Jun 2, 2022.csv
# [ok] teams_Jun 21, 2022.csv
# [ok] teams_Jun 22, 2017.csv
# [ok] teams_Jun 22, 2021.csv
# [ok] teams_Jun 23, 2016.csv
# [ok] teams_Jun 24, 2019.csv
# [ok] teams_Jun 24, 2020.csv
# [ok] teams_Jun 24, 2025.csv
# [ok] teams_Jun 26, 2015.csv
# [ok] teams_Jun 26, 2017.csv
# [ok] teams_Jun 26, 2024.csv
# [ok] teams_Jun 27, 2019.csv
# [ok] teams_Jun 27, 2023.csv
# [ok] teams_Jun 29, 2017.csv
# [ok] teams_Jun 3, 2019.csv
# [ok] teams_Jun 3, 2020.csv
# [ok] teams_Jun 3, 2025.csv
# [ok] teams_Jun 30, 2016.csv
# [ok] teams_Jun 30, 2021.csv
# [ok] teams_Jun 30, 2022.csv
# [ok] teams_Jun 4, 2018.csv
# [ok] teams_Jun 5, 2015.csv
# [ok] teams_Jun 5, 2023.csv
# [ok] teams_Jun 6, 2017.csv
# [ok] teams_Jun 6, 2019.csv
# [ok] teams_Jun 7, 2018.csv
# [ok] teams_Jun 7, 2023.csv
# [ok] teams_Jun 8, 2017.csv
# [ok] teams_Jun 9, 2016.csv
# [ok] teams_Jun 9, 2020.csv
# [ok] teams_Mar 1, 2018.csv
# [ok] teams_Mar 1, 2022.csv
# [ok] teams_Mar 10, 2015.csv
# [ok] teams_Mar 10, 2016.csv
# [ok] teams_Mar 10, 2020.csv
# [ok] teams_Mar 10, 2021.csv
# [ok] teams_Mar 10, 2022.csv
# [ok] teams_Mar 12, 2018.csv
# [ok] teams_Mar 12, 2021.csv
# [ok] teams_Mar 12, 2025.csv
# [ok] teams_Mar 13, 2015.csv
# [ok] teams_Mar 13, 2017.csv
# [ok] teams_Mar 14, 2019.csv
# [ok] teams_Mar 14, 2024.csv
# [ok] teams_Mar 15, 2018.csv
# [ok] teams_Mar 15, 2022.csv
# [ok] teams_Mar 16, 2017.csv
# [ok] teams_Mar 17, 2016.csv
# [ok] teams_Mar 18, 2019.csv
# [ok] teams_Mar 18, 2025.csv
# [ok] teams_Mar 19, 2018.csv
# [ok] teams_Mar 19, 2021.csv
# [ok] teams_Mar 2, 2017.csv
# [ok] teams_Mar 20, 2015.csv
# [ok] teams_Mar 20, 2017.csv
# [ok] teams_Mar 20, 2019.csv
# [ok] teams_Mar 20, 2020.csv
# [ok] teams_Mar 20, 2024.csv
# [ok] teams_Mar 20, 2025.csv
# [ok] teams_Mar 21, 2019.csv
# [ok] teams_Mar 22, 2018.csv
# [ok] teams_Mar 22, 2022.csv
# [ok] teams_Mar 23, 2017.csv
# [ok] teams_Mar 24, 2016.csv
# [ok] teams_Mar 24, 2023.csv
# [ok] teams_Mar 25, 2019.csv
# [ok] teams_Mar 25, 2022.csv
# [ok] teams_Mar 25, 2025.csv
# [ok] teams_Mar 26, 2018.csv
# [ok] teams_Mar 26, 2021.csv
# [ok] teams_Mar 27, 2015.csv
# [ok] teams_Mar 27, 2017.csv
# [ok] teams_Mar 27, 2024.csv
# [ok] teams_Mar 28, 2019.csv
# [ok] teams_Mar 29, 2018.csv
# [ok] teams_Mar 3, 2016.csv
# [ok] teams_Mar 3, 2020.csv
# [ok] teams_Mar 3, 2023.csv
# [ok] teams_Mar 30, 2017.csv
# [ok] teams_Mar 30, 2021.csv
# [ok] teams_Mar 30, 2022.csv
# [ok] teams_Mar 30, 2023.csv
# [ok] teams_Mar 31, 2016.csv
# [ok] teams_Mar 31, 2020.csv
# [ok] teams_Mar 31, 2022.csv
# [ok] teams_Mar 4, 2019.csv
# [ok] teams_Mar 4, 2021.csv
# [ok] teams_Mar 5, 2018.csv
# [ok] teams_Mar 5, 2024.csv
# [ok] teams_Mar 5, 2025.csv
# [ok] teams_Mar 6, 2015.csv
# [ok] teams_Mar 6, 2017.csv
# [ok] teams_Mar 6, 2021.csv
# [ok] teams_Mar 6, 2024.csv
# [ok] teams_Mar 7, 2022.csv
# [ok] teams_Mar 7, 2023.csv
# [ok] teams_Mar 7, 2024.csv
# [ok] teams_Mar 8, 2018.csv
# [ok] teams_Mar 9, 2017.csv
# [ok] teams_May 1, 2015.csv
# [ok] teams_May 1, 2025.csv
# [ok] teams_May 10, 2018.csv
# [ok] teams_May 10, 2022.csv
# [ok] teams_May 11, 2017.csv
# [ok] teams_May 11, 2023.csv
# [ok] teams_May 12, 2016.csv
# [ok] teams_May 12, 2022.csv
# [ok] teams_May 14, 2018.csv
# [ok] teams_May 14, 2020.csv
# [ok] teams_May 15, 2015.csv
# [ok] teams_May 15, 2017.csv
# [ok] teams_May 16, 2023.csv
# [ok] teams_May 17, 2018.csv
# [ok] teams_May 17, 2022.csv
# [ok] teams_May 18, 2017.csv
# [ok] teams_May 18, 2021.csv
# [ok] teams_May 19, 2016.csv
# [ok] teams_May 19, 2020.csv
# [ok] teams_May 19, 2022.csv
# [ok] teams_May 2, 2017.csv
# [ok] teams_May 2, 2019.csv
# [ok] teams_May 20, 2020.csv
# [ok] teams_May 21, 2025.csv
# [ok] teams_May 22, 2015.csv
# [ok] teams_May 22, 2017.csv
# [ok] teams_May 22, 2018.csv
# [ok] teams_May 22, 2024.csv
# [ok] teams_May 23, 2019.csv
# [ok] teams_May 24, 2018.csv
# [ok] teams_May 24, 2023.csv
# [ok] teams_May 25, 2017.csv
# [ok] teams_May 26, 2016.csv
# [ok] teams_May 26, 2023.csv
# [ok] teams_May 27, 2019.csv
# [ok] teams_May 27, 2020.csv
# [ok] teams_May 27, 2021.csv
# [ok] teams_May 27, 2022.csv
# [ok] teams_May 28, 2018.csv
# [ok] teams_May 29, 2015.csv
# [ok] teams_May 29, 2017.csv
# [ok] teams_May 3, 2018.csv
# [ok] teams_May 3, 2022.csv
# [ok] teams_May 30, 2019.csv
# [ok] teams_May 31, 2018.csv
# [ok] teams_May 4, 2017.csv
# [ok] teams_May 5, 2016.csv
# [ok] teams_May 5, 2023.csv
# [ok] teams_May 6, 2020.csv
# [ok] teams_May 6, 2022.csv
# [ok] teams_May 7, 2019.csv
# [ok] teams_May 7, 2024.csv
# [ok] teams_May 7, 2025.csv
# [ok] teams_May 8, 2015.csv
# [ok] teams_May 8, 2017.csv
# [ok] teams_May 8, 2018.csv
# [ok] teams_May 8, 2024.csv
# [ok] teams_May 9, 2019.csv
# [ok] teams_Nov 1, 2018.csv
# [ok] teams_Nov 1, 2023.csv
# [ok] teams_Nov 10, 2016.csv
# [ok] teams_Nov 12, 2015.csv
# [ok] teams_Nov 13, 2017.csv
# [ok] teams_Nov 13, 2018.csv
# [ok] teams_Nov 13, 2019.csv
# [ok] teams_Nov 13, 2020.csv
# [ok] teams_Nov 14, 2016.csv
# [ok] teams_Nov 15, 2018.csv
# [ok] teams_Nov 15, 2023.csv
# [ok] teams_Nov 16, 2017.csv
# [ok] teams_Nov 16, 2022.csv
# [ok] teams_Nov 17, 2016.csv
# [ok] teams_Nov 17, 2020.csv
# [ok] teams_Nov 19, 2015.csv
# [ok] teams_Nov 19, 2019.csv
# [ok] teams_Nov 2, 2017.csv
# [ok] teams_Nov 20, 2017.csv
# [ok] teams_Nov 20, 2020.csv
# [ok] teams_Nov 20, 2023.csv
# [ok] teams_Nov 20, 2024.csv
# [ok] teams_Nov 21, 2016.csv
# [ok] teams_Nov 21, 2024.csv
# [ok] teams_Nov 22, 2019.csv
# [ok] teams_Nov 22, 2021.csv
# [ok] teams_Nov 23, 2017.csv
# [ok] teams_Nov 23, 2021.csv
# [ok] teams_Nov 24, 2016.csv
# [ok] teams_Nov 24, 2023.csv
# [ok] teams_Nov 26, 2015.csv
# [ok] teams_Nov 26, 2018.csv
# [ok] teams_Nov 27, 2017.csv
# [ok] teams_Nov 27, 2020.csv
# [ok] teams_Nov 27, 2024.csv
# [ok] teams_Nov 28, 2016.csv
# [ok] teams_Nov 28, 2020.csv
# [ok] teams_Nov 3, 2016.csv
# [ok] teams_Nov 30, 2017.csv
# [ok] teams_Nov 4, 2020.csv
# [ok] teams_Nov 5, 2018.csv
# [ok] teams_Nov 5, 2021.csv
# [ok] teams_Nov 5, 2024.csv
# [ok] teams_Nov 6, 2015.csv
# [ok] teams_Nov 6, 2017.csv
# [ok] teams_Nov 6, 2019.csv
# [ok] teams_Nov 6, 2020.csv
# [ok] teams_Nov 6, 2024.csv
# [ok] teams_Nov 7, 2016.csv
# [ok] teams_Nov 9, 2021.csv
# [ok] teams_Nov 9, 2023.csv
# [ok] teams_Oct 1, 2018.csv
# [ok] teams_Oct 1, 2019.csv
# [ok] teams_Oct 1, 2020.csv
# [ok] teams_Oct 1, 2021.csv
# [ok] teams_Oct 10, 2023.csv
# [ok] teams_Oct 11, 2018.csv
# [ok] teams_Oct 12, 2017.csv
# [ok] teams_Oct 12, 2023.csv
# [ok] teams_Oct 13, 2016.csv
# [ok] teams_Oct 14, 2021.csv
# [ok] teams_Oct 15, 2018.csv
# [ok] teams_Oct 16, 2015.csv
# [ok] teams_Oct 16, 2017.csv
# [ok] teams_Oct 16, 2019.csv
# [ok] teams_Oct 16, 2020.csv
# [ok] teams_Oct 16, 2023.csv
# [ok] teams_Oct 17, 2024.csv
# [ok] teams_Oct 18, 2018.csv
# [ok] teams_Oct 19, 2015.csv
# [ok] teams_Oct 19, 2016.csv
# [ok] teams_Oct 19, 2017.csv
# [ok] teams_Oct 2, 2015.csv
# [ok] teams_Oct 2, 2017.csv
# [ok] teams_Oct 2, 2024.csv
# [ok] teams_Oct 20, 2021.csv
# [ok] teams_Oct 22, 2018.csv
# [ok] teams_Oct 22, 2021.csv
# [ok] teams_Oct 22, 2024.csv
# [ok] teams_Oct 23, 2015.csv
# [ok] teams_Oct 23, 2017.csv
# [ok] teams_Oct 23, 2018.csv
# [ok] teams_Oct 23, 2023.csv
# [ok] teams_Oct 25, 2018.csv
# [ok] teams_Oct 26, 2017.csv
# [ok] teams_Oct 26, 2023.csv
# [ok] teams_Oct 27, 2016.csv
# [ok] teams_Oct 27, 2020.csv
# [ok] teams_Oct 27, 2021.csv
# [ok] teams_Oct 28, 2021.csv
# [ok] teams_Oct 28, 2022.csv
# [ok] teams_Oct 29, 2018.csv
# [ok] teams_Oct 29, 2019.csv
# [ok] teams_Oct 29, 2020.csv
# [ok] teams_Oct 30, 2015.csv
# [ok] teams_Oct 30, 2017.csv
# [ok] teams_Oct 30, 2023.csv
# [ok] teams_Oct 4, 2018.csv
# [ok] teams_Oct 4, 2019.csv
# [ok] teams_Oct 4, 2023.csv
# [ok] teams_Oct 5, 2017.csv
# [ok] teams_Oct 5, 2020.csv
# [ok] teams_Oct 5, 2023.csv
# [ok] teams_Oct 6, 2016.csv
# [ok] teams_Oct 7, 2022.csv
# [ok] teams_Oct 8, 2024.csv
# [ok] teams_Oct 9, 2015.csv
# [ok] teams_Oct 9, 2017.csv
# [ok] teams_Oct 9, 2018.csv
# [ok] teams_Oct 9, 2020.csv
# [ok] teams_Sep 1, 2015.csv
# [ok] teams_Sep 1, 2016.csv
# [ok] teams_Sep 1, 2022.csv
# [ok] teams_Sep 10, 2015.csv
# [ok] teams_Sep 10, 2020.csv
# [ok] teams_Sep 11, 2017.csv
# [ok] teams_Sep 11, 2019.csv
# [ok] teams_Sep 11, 2023.csv
# [ok] teams_Sep 12, 2018.csv
# [ok] teams_Sep 13, 2017.csv
# [ok] teams_Sep 14, 2016.csv
# [ok] teams_Sep 17, 2020.csv
# [ok] teams_Sep 17, 2021.csv
# [ok] teams_Sep 18, 2017.csv
# [ok] teams_Sep 19, 2019.csv
# [ok] teams_Sep 2, 2020.csv
# [ok] teams_Sep 2, 2021.csv
# [ok] teams_Sep 20, 2016.csv
# [ok] teams_Sep 20, 2017.csv
# [ok] teams_Sep 20, 2018.csv
# [ok] teams_Sep 20, 2024.csv
# [ok] teams_Sep 21, 2015.csv
# [ok] teams_Sep 21, 2017.csv
# [ok] teams_Sep 21, 2021.csv
# [ok] teams_Sep 22, 2016.csv
# [ok] teams_Sep 22, 2023.csv
# [ok] teams_Sep 23, 2020.csv
# [ok] teams_Sep 23, 2021.csv
# [ok] teams_Sep 24, 2018.csv
# [ok] teams_Sep 25, 2015.csv
# [ok] teams_Sep 25, 2017.csv
# [ok] teams_Sep 25, 2021.csv
# [ok] teams_Sep 26, 2019.csv
# [ok] teams_Sep 26, 2022.csv
# [ok] teams_Sep 26, 2023.csv
# [ok] teams_Sep 26, 2024.csv
# [ok] teams_Sep 27, 2018.csv
# [ok] teams_Sep 27, 2019.csv
# [ok] teams_Sep 27, 2021.csv
# [ok] teams_Sep 28, 2017.csv
# [ok] teams_Sep 28, 2021.csv
# [ok] teams_Sep 28, 2022.csv
# [ok] teams_Sep 29, 2016.csv
# [ok] teams_Sep 4, 2015.csv
# [ok] teams_Sep 4, 2017.csv
# [ok] teams_Sep 4, 2024.csv
# [ok] teams_Sep 6, 2018.csv
# [ok] teams_Sep 7, 2017.csv
# [ok] teams_Sep 8, 2016.csv
# [ok] teams_Sep 8, 2023.csv
#
# Master CSV created: G:\My Drive\GitHubProjects\MLS\data\scraping\teams\teams_master.csv

# %%
master = pd.read_csv(OUTPUT_FILE)

# %%
master.head()
# Out:
#          date                 name      id formation_base formation_style  \
# 0  2015-04-01           Toronto FC  111651          4-3-3         false 9
# 1  2015-04-01  Seattle Sounders FC  111144        4-2-3-1            wide
# 2  2015-04-01   Philadelphia Union  112134        4-2-3-1            wide
# 3  2015-04-01          CF Montréal  111139        4-2-3-1          narrow
# 4  2015-04-01     Portland Timbers  111140          4-4-2            flat
#
#    overall  attack  midfield  defence club_worth  players
# 0       68      68        70       64         €0       30
# 1       68      74        65       66         €0       28
# 2       67      68        67       65         €0       27
# 3       67      68        67       64         €0       29
# 4       67      65        66       65         €0       28

# %%
## rename id to team id

master = master.rename(columns={'id': 'team_id'})

# %%
db_string = 'mysql+pymysql://mls_admin:Got2beweird!@100.120.74.41:2022/MLS'

engine = create_engine(db_string)

# %%
master.to_sql('teams_stats', con=engine, if_exists='append', index=False)
# Out:
# 16327
