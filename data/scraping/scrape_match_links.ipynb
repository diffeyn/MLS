# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
import math
import re
from pathlib import Path

# %%
options = Options()
options.add_argument('--disable-gpu')
options.add_argument('--no-sandbox')
options.add_argument('--start-maximized')
options.add_argument('--disable-infobars')  
options.add_argument('--disable-extensions')


service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# %%
url = 'https://www.mlssoccer.com/schedule/scores#competition=MLS-COM-000001&club=all'

driver.get(url)
time.sleep(5) 
wait = WebDriverWait(driver, 10)

all_links = set()

rounds = 2000
stop_date = "Wednesday Oct 18, 2023"


for i in range(rounds):
    try:
        previous_button = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, 'button[aria-label="Previous results"]')))
        time.sleep(5)
        
        matches_table = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'mls-c-schedule__matches')))
        if not matches_table:
            print("No matches table found on this page.")
            previous_button.click()
            continue
        
        date_headers = matches_table.find_elements(By.CSS_SELECTOR, 'h2.sc-hLBbgP.gIKMo')
        if date_headers:
            first_date_text = date_headers[0].text.strip()
            print("First date header:", first_date_text)
            if first_date_text == stop_date:
                print("Reached stop date.")
                break
        
        hrefs = matches_table.find_elements(By.TAG_NAME, 'a')
        if not hrefs:
            print("No match links found on this page.")
            previous_button.click()
            continue
        
        for href in hrefs:
            print(href.get_attribute('href'))
            all_links.add(href.get_attribute('href'))
            

        previous_button.click()

    except Exception as e:
        print(f"Error occurred: {e}")
        continue
print(f"Total unique match links collected: {len(all_links)}")

driver.quit()
# Out:
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# First date header: Saturday Oct 18
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/atlvsdc-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/cltvsphi-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/cinvsmtl-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/clbvsrbny-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nshvsmia-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nevschi-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nycvssea-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/torvsorl-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/colvslafc-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/skcvshou-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/lavsmin-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/porvssd-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/sjvsatx-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/stlvsrsl-10-18-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/vanvsdal-10-18-2025
# First date header: Wednesday Oct 8
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/lafcvstor-10-08-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/miavsatl-10-11-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/orlvsvan-10-11-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/seavsrsl-10-11-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/lavsdal-10-11-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/atxvslafc-10-12-2025
# First date header: Tuesday Sep 30
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/miavschi-09-30-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/dcvsclt-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/mtlvsnsh-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/dalvsla-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/miavsne-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/rbnyvscin-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/orlvsclb-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/phivsnyc-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/atxvsstl-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/chivstor-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/houvssd-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/minvsskc-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/rslvscol-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/seavspor-10-04-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/vanvssj-10-05-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/lafcvsatl-10-05-2025
# First date header: Wednesday Sep 24
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nycvsmia-09-24-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/vanvspor-09-24-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/torvsmia-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/cltvsmtl-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/dcvsphi-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nevsatl-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/rbnyvsnyc-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/chivsclb-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nshvshou-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/stlvslafc-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/colvsmin-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/rslvsatx-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/lavsskc-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/porvsdal-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/sdvssj-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/seavsvan-09-27-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/cinvsorl-09-28-2025
# First date header: Tuesday Sep 16
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/miavssea-09-16-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nycvsclb-09-17-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/rslvslafc-09-17-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nycvsclt-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/phivsne-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/atlvssd-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/clbvstor-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/miavsdc-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/mtlvsrbny-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/orlvsnsh-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/dalvscol-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/houvspor-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/skcvsvan-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/minvschi-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/lavscin-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/sjvsstl-09-20-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/atxvssea-09-21-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/lafcvsrsl-09-21-2025
# First date header: Saturday Sep 13
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/atlvsclb-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/cltvsmia-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/cinvsnsh-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/dcvsorl-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/mtlvsstl-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nevstor-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/chivsnyc-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/dalvsatx-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/seavsla-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/sjvslafc-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/colvshou-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/rslvsskc-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/vanvsphi-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/porvsrbny-09-13-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/sdvsmin-09-13-2025
# First date header: Saturday Sep 6
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/houvsla-09-06-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/chivsne-09-06-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/stlvsdal-09-06-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/skcvsatx-09-07-2025
# First date header: Saturday Aug 30
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/cinvsphi-08-30-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nevsclt-08-30-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nycvsdc-08-30-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/rbnyvsclb-08-30-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/torvsmtl-08-30-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/atxvssj-08-30-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/stlvshou-08-30-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/skcvscol-08-30-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/minvspor-08-30-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nshvsatl-08-30-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/lafcvssd-08-31-2025
# First date header: Saturday Aug 23
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/cinvsnyc-08-23-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/clbvsne-08-23-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/dcvsmia-08-23-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/mtlvsatx-08-23-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/phivschi-08-23-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/dalvslafc-08-23-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/houvssj-08-23-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nshvsorl-08-23-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/rslvsmin-08-23-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/vanvsstl-08-23-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/lavscol-08-23-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/sdvspor-08-23-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/atlvstor-08-24-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/cltvsrbny-08-24-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/seavsskc-08-24-2025
# First date header: Saturday Aug 16
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/cltvsrsl-08-16-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/miavsla-08-16-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/mtlvsdc-08-16-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/nevslafc-08-16-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/rbnyvsphi-08-16-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/torvsclb-08-16-2025
# https://www.mlssoccer.com/competitions/mls-regular-season/undefined/matches/atxv
04-20-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/skcvsstl-04-20-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/colvsdal-04-20-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/lafcvsrbny-04-20-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/seavsvan-04-20-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/cltvsmin-04-21-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/lavssj-04-21-2024
# First date header: Saturday Apr 13, 2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/porvslafc-04-13-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/mtlvscin-04-13-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/cltvstor-04-13-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/dcvsorl-04-13-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nycvsne-04-13-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/rbnyvschi-04-13-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/dalvssea-04-13-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/minvshou-04-13-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/skcvsmia-04-13-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/rslvsclb-04-13-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/vanvsla-04-13-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/sjvscol-04-13-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/atlvsphi-04-14-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/stlvsatx-04-14-2024
# First date header: Saturday Apr 6, 2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/vanvstor-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/clbvsdc-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/cinvsrbny-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/miavscol-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nevsclt-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nycvsatl-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/lafcvsla-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/atxvssj-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/chivshou-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/minvsrsl-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nshvsphi-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/stlvsdal-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/seavsmtl-04-06-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/skcvspor-04-07-2024
# First date header: Saturday Mar 30, 2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/phivsmin-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/colvslafc-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/cltvscin-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/dcvsmtl-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/miavsnyc-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/orlvsrbny-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/torvsskc-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/atxvsdal-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/houvssj-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nshvsclb-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/rslvsstl-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/vanvspor-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/lavssea-03-30-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/atlvschi-03-31-2024
# First date header: Saturday Mar 23, 2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nevschi-03-23-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/rbnyvsmia-03-23-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/cltvsclb-03-23-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/cinvsnyc-03-23-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/orlvsatx-03-23-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/torvsatl-03-23-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/vanvsrsl-03-23-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/skcvsla-03-23-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/stlvsdc-03-23-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/colvshou-03-23-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/lafcvsnsh-03-23-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/porvsphi-03-23-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/sjvssea-03-23-2024
# First date header: Saturday Mar 16, 2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/chivsmtl-03-16-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/dcvsmia-03-16-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/seavscol-03-16-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/clbvsrbny-03-16-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nycvstor-03-16-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/atxvsphi-03-16-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/dalvsvan-03-16-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/houvspor-03-16-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/minvslafc-03-16-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nshvsclt-03-16-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/skcvssj-03-16-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/lavsstl-03-16-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nevscin-03-17-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/atlvsorl-03-17-2024
# First date header: Saturday Mar 9, 2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nycvspor-03-09-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/torvsclt-03-09-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/atlvsne-03-09-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/clbvschi-03-09-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/rbnyvsdal-03-09-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/orlvsmin-03-09-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/atxvsstl-03-09-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/rslvscol-03-09-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/lafcvsskc-03-09-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/sjvsvan-03-09-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/cinvsdc-03-10-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nshvsla-03-10-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/miavsmtl-03-10-2024
# First date header: Saturday Mar 2, 2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/minvsclb-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/rslvslafc-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/miavsorl-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/vanvsclt-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/chivscin-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/dalvsmtl-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/houvsrbny-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/skcvsphi-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/stlvsnyc-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/colvsnsh-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/porvsdc-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/sjvsla-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/seavsatx-03-02-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nevstor-03-03-2024
# First date header: Wednesday Feb 21, 2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/miavsrsl-02-21-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/clbvsatl-02-24-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/lafcvssea-02-24-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/cltvsnyc-02-24-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/dcvsne-02-24-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/orlvsmtl-02-24-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/phivschi-02-24-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/atxvsmin-02-24-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/dalvssj-02-24-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/houvsskc-02-24-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/stlvsrsl-02-24-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/porvscol-02-24-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/cinvstor-02-25-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/nshvsrbny-02-25-2024
# https://www.mlssoccer.com/competitions/mls-regular-season/2024/matches/lavsmia-02-25-2024
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# No match links found on this page.
# First date header: Wednesday Oct 18, 2023
# Reached stop date.
# Total unique match links collected: 1003

# %%
all_links_df = pd.DataFrame(all_links, columns=['Match Links'])

all_links_df.to_csv('mls_match_links.csv', index=False)

# %%
links = pd.read_csv('../data/mls_match_links.csv')
links = links['Match Links'].tolist()

# %%
def js_scroll_by(driver, dy):
    driver.execute_script("window.scrollBy(0, arguments[0]);", dy)



def js_scroll_into_view(driver, el):
    driver.execute_script(
        "arguments[0].scrollIntoView({block:'center', inline:'nearest'});", el)


def js_hover(driver, el):
    driver.execute_script(
        """
        const el = arguments[0];
        const rect = el.getBoundingClientRect();
        const x = Math.floor(rect.left + rect.width/2);
        const y = Math.floor(rect.top  + rect.height/2);
        ['pointerover','mouseover','mouseenter','mousemove'].forEach(type => {
            el.dispatchEvent(new MouseEvent(type, {bubbles:true, cancelable:true, clientX:x, clientY:y, view:window}));
        });
    """, el)
    
def scrape_cards(group):
    return driver.execute_script("""
        const root = arguments[0];
        return [...root.querySelectorAll('.mls-o-stat-chart')].map(c => ({
        stat:   c.querySelector('.mls-o-stat-chart__header')?.textContent.trim() || '',
        first:  c.querySelector('.mls-o-stat-chart__first-value')?.textContent.trim() || '',
        second: c.querySelector('.mls-o-stat-chart__second-value')?.textContent.trim() || '',
        }));
    """, group)
    
def make_match_id(link: str) -> str:
    mid = link.rstrip("/").split("/")[-1].split("?")[0]
    return re.sub(r"[^A-Za-z0-9._-]+", "_", mid)

# %%
"""
FEED_DIR = Path('../data/scraping/matches/feed')


wait = WebDriverWait(driver, 6, poll_frequency=0.2)

for link in links:
    if (link is None or (isinstance(link, float) and math.isnan(link))
            or str(link).strip() == '' or str(link).strip().lower() == 'nan'):
        print(f"[skip] bad link: {link!r}")
        continue
    
    match_id = link.rstrip('/').split('/')[-1].split('?')[0]
    feed_path = FEED_DIR / f"feed_{match_id}.csv"

    if feed_path.exists():
        print(f"[skip] feed already done for {match_id}")
        continue

    feed = []


    try:
        driver.get(link)
        time.sleep(5)

        feed_bttn = driver.find_element(By.LINK_TEXT, 'Feed')

        try:
            feed_bttn.click()

            driver.execute_script(
                "window.scrollTo(0, (document.documentElement.scrollHeight - window.innerHeight) * 0.85);"
            )
            time.sleep(5)

            driver.execute_script(
                "window.scrollTo(0, (document.documentElement.scrollHeight - window.innerHeight) * 0.90);"
            )
            time.sleep(5)

            driver.execute_script(
                "window.scrollTo(0, (document.documentElement.scrollHeight - window.innerHeight) * 0.90);"
            )

            wait.until(
                EC.presence_of_element_located(
                    (By.XPATH,
                        "//*[normalize-space(text())='First half begins.']")))


            cont = driver.find_element(By.CSS_SELECTOR, 'div[class="mls-o-match-feed"]')

            for event in cont.find_elements(
                    By.XPATH,
                    './/div[contains(@class,"mls-o-match-feed__container")]'):
                minute_el = event.find_elements(By.CSS_SELECTOR, ".mls-o-match-feed__minute .mls-o-match-summary__regular-time")
                minute = minute_el[0].text.strip() if minute_el else None

                title_el = event.find_elements(By.CSS_SELECTOR, ".mls-o-match-feed__title")
                title = title_el[0].text.strip() if title_el else None

                comment_el = event.find_elements(By.CSS_SELECTOR, ".mls-o-match-feed__comment")
                comment = comment_el[0].text.strip() if comment_el else None

                feed.append({
                    'match_id': match_id,
                    'minute': minute,
                    'title': title,
                    'comment': comment
                })
        except Exception as e:
            print(f"Error processing feed for link {link}: {e}")
    except Exception as e:
        print(f"Error occurred while loading feed for link {link}: {e}")

    feed = pd.DataFrame(feed)

    general_stats = []
    shooting_stats = []
    passing_stats = []
    possession_stats = []
    xg_stats = []

    stats_bttn = driver.find_element(By.LINK_TEXT, 'Stats')

    try:
        stats_bttn.click()
        time.sleep(5)

        try:
            general_cont = wait.until(
                EC.presence_of_element_located((
                    By.XPATH,
                    '//section[contains(@class,"mls-l-module--stats-comparison")'
                    ' and contains(@class,"mls-l-module--general")'
                    ' and not(contains(@style,"display: none"))]')))


            js_scroll_into_view(driver, general_cont)
            general_cards = scrape_cards(general_cont)

            for it in general_cards:
                shooting_stats.append({
                    'stat_name': it['stat'],
                    'home_value': it['first'],
                    'away_value': it['second']
                })
        except Exception as e:
            print(f"Error occurred while scraping general stats: {e}")

        try:
            clubs_wrap = wait.until(
                EC.visibility_of_element_located((
                    By.XPATH,
                    '//section[contains(@class,"d3-l-section-row")][@data-toggle="clubs" and not(contains(@style,"display: none"))]'
                )))

            shooting_cont = clubs_wrap.find_element(
                By.XPATH,
                './/section[contains(@class,"mls-l-module--shooting-breakdown")]'
            )

            driver.execute_script(
                "arguments[0].scrollIntoView({block:'center'});",
                shooting_cont)

            shooting_cards = scrape_cards(shooting_cont)

            for it in shooting_cards:
                shooting_stats.append({
                    'stat_name': it['stat'],
                    'home_value': it['first'],
                    'away_value': it['second']
                })

        except Exception as e:
            print(f"Error occurred while scraping shooting stats: {e}")

        try:
            passing_cont = driver.find_element(By.XPATH, '//section[contains(@class,"passing-breakdown")]')

            passing_cards = scrape_cards(passing_cont)
            for it in passing_cards:
                passing_stats.append({
                    'stat_name': it['stat'],
                    'home_value': it['first'],
                    'away_value': it['second']
                })

        except Exception as e:
            print(f"Error occurred while scraping passing stats: {e}")

        try:
            possession_cont = driver.find_element(By.XPATH, '//section[contains(@class,"--possession")]')
            bar_cont = possession_cont.find_element(By.XPATH, './/*[contains(@class,"mls-o-possession__intervals")]')

            driver.execute_script(
                "arguments[0].scrollIntoView({block:'center'});",
                bar_cont)


            for bar in bar_cont.find_elements(By.XPATH, './/div[contains(@class,"mls-o-possession__average-intervals")]'):
                tip_id = bar.get_attribute('data-for')

                tooltips = bar.find_elements(By.XPATH, './/div[contains(@class,"__react_component_tooltip")]')

                tip = wait.until(EC.presence_of_element_located((By.ID, tip_id)))

                spans = tip.find_elements(By.XPATH, './/span')

                texts = [s.get_attribute('textContent').strip() for s in spans]
                texts = [t for t in texts if t and t.upper() != 'SKIP TO MAIN CONTENT']

                if len(texts) >= 4:
                    home_poss, home_adv, away_poss, away_adv = texts[:4]
                else:
                    home_poss = home_adv = away_poss = away_adv = None

                possession_stats.append({
                    'tip_id': tip_id,
                    'home_possession': home_poss,
                    'home_advantage': home_adv,
                    'away_possession': away_poss,
                    'away_advantage': away_adv
                })
        except Exception as e:
            print(f"Error occurred while scraping possession stats: {e}")

        try:
            xg_mod_xpath = (
                '//section[@data-toggle="clubs" and not(contains(@style,"display: none"))]'
                '//section[contains(@class,"mls-l-module--expected-goals")]'
            )
            xg_mod = wait.until(EC.visibility_of_element_located((By.XPATH, xg_mod_xpath)))

            groups = xg_mod.find_elements(
                By.CSS_SELECTOR,
                '.mls-o-expected-goals__chart-group, .mls-o-expected-goals__club-group'
            )
            chart_group = next(
                (g for g in groups if 'mls-o-expected-goals__chart-group' in (g.get_attribute('class') or '')),
                None
            )
            if chart_group is None:
                raise Exception("xG chart-group not found")

            # ensure cards exist
            wait.until(lambda d: any(
                e.is_displayed() for e in chart_group.find_elements(By.CSS_SELECTOR, '.mls-o-stat-chart')
            ))

            for card in chart_group.find_elements(By.CSS_SELECTOR, '.mls-o-stat-chart'):
                header = card.find_element(By.CSS_SELECTOR,  '.mls-o-stat-chart__header')
                first  = card.find_element(By.CSS_SELECTOR,  '.mls-o-stat-chart__first-value')
                second = card.find_element(By.CSS_SELECTOR,  '.mls-o-stat-chart__second-value')

                stat_name  = (header.text or header.get_attribute('textContent') or '').strip()
                home_value = (first.text  or first.get_attribute('textContent')  or '').strip()
                away_value = (second.text or second.get_attribute('textContent') or '').strip()

                xg_stats.append({
                    'stat_name': stat_name,
                    'home_value': home_value,
                    'away_value': away_value
                })
        except Exception as e:
            print(f"Error occurred while scraping expected goals stats: {e}")

    except Exception as e:
        print(f"Error occurred while scraping stats: {e}")
        pass

    player_rows = []
    gk_rows = []

    try:
        js_scroll_by(driver, -3000)
        time.sleep(2)

        player_btn = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.mls-o-buttons__segment[value="players"]')))
        player_btn.click()


        players_mod = wait.until(EC.visibility_of_element_located((
            By.XPATH,
            '//section[contains(@class,"mls-l-module--match-hub-player-stats") and not(contains(@style,"display: none"))]'
        )))

        js_scroll_into_view(driver, players_mod)

        club_blocks = players_mod.find_elements(By.CSS_SELECTOR, '.mls-c-stats--match-hub-player-stats')

        for idx, block in enumerate(club_blocks):
            side = 'home' if idx == 0 else 'away'
            club_abbrev_el = block.find_elements(By.CSS_SELECTOR, '.mls-c-stats__club-abbreviation')
            club_abbrev = club_abbrev_el[0].text.strip() if club_abbrev_el else None

            for tbl in block.find_elements(By.CSS_SELECTOR, 'table.mls-o-table'):
                cls = (tbl.get_attribute('class') or '').lower()
                is_gk = 'goalkeeper' in cls

                header_cells = tbl.find_elements(
                    By.CSS_SELECTOR,
                    'thead .mls-o-table__header-group:not(.mls-o-table__header-group--main) .mls-o-table__header'
                )
                if not header_cells:
                    header_cells = tbl.find_elements(By.CSS_SELECTOR, 'thead .mls-o-table__header')

                headers = [(h.text or h.get_attribute('textContent') or '').strip() for h in header_cells]

                for tr in tbl.find_elements(By.CSS_SELECTOR, 'tbody .mls-o-table__row'):
                    cells = tr.find_elements(By.CSS_SELECTOR, '.mls-o-table__cell')
                    values = [(c.text or c.get_attribute('textContent') or '').strip() for c in cells]

                    if len(values) < len(headers):
                        values += [''] * (len(headers) - len(values))
                    elif len(values) > len(headers):
                        values = values[:len(headers)]

                    row = dict(zip(headers, values))
                    row.update({
                        'match_id': match_id,
                        'side': side,
                        'club': club_abbrev
                    })

                    if is_gk:
                        gk_rows.append(row)
                    else:
                        player_rows.append(row)

                    combined_rows = player_rows + gk_rows

    except Exception as e:
        print(f"Error occurred while scraping player stats: {e}")



    general_stats_df = pd.DataFrame(general_stats);  general_stats_df["category"] = "general"
    shooting_stats_df = pd.DataFrame(shooting_stats); shooting_stats_df["category"] = "shooting"
    passing_stats_df = pd.DataFrame(passing_stats);   passing_stats_df["category"] = "passing"
    possession_stats_df = pd.DataFrame(possession_stats); possession_stats_df["category"] = "possession"
    expected_goals_stats_df = pd.DataFrame(xg_stats); expected_goals_stats_df["category"] = "xg"
    player_stats_df = pd.DataFrame(combined_rows)

    all_stats = pd.concat(
        [general_stats_df, shooting_stats_df, passing_stats_df, possession_stats_df, expected_goals_stats_df],
        axis=0, ignore_index=True
    )

    feed.to_csv(f"../data/scraping/matches/feed/feed_{match_id}.csv", index=False)
    all_stats.to_csv(f"../data/scraping/matches/stats/stats_{match_id}.csv", index=False)
    player_stats_df.to_csv(f"../data/scraping/matches/players/player_stats_{match_id}.csv", index=False)

driver.quit()
"""
# Out:
# '\nFEED_DIR = Path(\'../data/scraping/matches/feed\')\n\n\nwait = WebDriverWait(driver, 6, poll_frequency=0.2)\n\nfor link in links:\n    if (link is None or (isinstance(link, float) and math.isnan(link))\n            or str(link).strip() == \'\' or str(link).strip().lower() == \'nan\'):\n        print(f"[skip] bad link: {link!r}")\n        continue\n\n    match_id = link.rstrip(\'/\').split(\'/\')[-1].split(\'?\')[0]\n    feed_path = FEED_DIR / f"feed_{match_id}.csv"\n\n    if feed_path.exists():\n        print(f"[skip] feed already done for {match_id}")\n        continue\n\n    feed = []\n\n\n    try:\n        driver.get(link)\n        time.sleep(5)\n\n        feed_bttn = driver.find_element(By.LINK_TEXT, \'Feed\')\n\n        try:\n            feed_bttn.click()\n\n            driver.execute_script(\n                "window.scrollTo(0, (document.documentElement.scrollHeight - window.innerHeight) * 0.85);"\n            )\n            time.sleep(5)\n\n            driver.execute_script(\n                "window.scrollTo(0, (document.documentElement.scrollHeight - window.innerHeight) * 0.90);"\n            )\n            time.sleep(5)\n\n            driver.execute_script(\n                "window.scrollTo(0, (document.documentElement.scrollHeight - window.innerHeight) * 0.90);"\n            )\n\n            wait.until(\n                EC.presence_of_element_located(\n                    (By.XPATH,\n                        "//*[normalize-space(text())=\'First half begins.\']")))\n\n\n            cont = driver.find_element(By.CSS_SELECTOR, \'div[class="mls-o-match-feed"]\')\n\n            for event in cont.find_elements(\n                    By.XPATH,\n                    \'.//div[contains(@class,"mls-o-match-feed__container")]\'):\n                minute_el = event.find_elements(By.CSS_SELECTOR, ".mls-o-match-feed__minute .mls-o-match-summary__regular-time")\n                minute = minute_el[0].text.strip() if minute_el else None\n\n                title_el = event.find_elements(By.CSS_SELECTOR, ".mls-o-match-feed__title")\n                title = title_el[0].text.strip() if title_el else None\n\n                comment_el = event.find_elements(By.CSS_SELECTOR, ".mls-o-match-feed__comment")\n                comment = comment_el[0].text.strip() if comment_el else None\n\n                feed.append({\n                    \'match_id\': match_id,\n                    \'minute\': minute,\n                    \'title\': title,\n                    \'comment\': comment\n                })\n        except Exception as e:\n            print(f"Error processing feed for link {link}: {e}")\n    except Exception as e:\n        print(f"Error occurred while loading feed for link {link}: {e}")\n\n    feed = pd.DataFrame(feed)\n\n    general_stats = []\n    shooting_stats = []\n    passing_stats = []\n    possession_stats = []\n    xg_stats = []\n\n    stats_bttn = driver.find_element(By.LINK_TEXT, \'Stats\')\n\n    try:\n        stats_bttn.click()\n        time.sleep(5)\n\n        try:\n            general_cont = wait.until(\n                EC.presence_of_element_located((\n                    By.XPATH,\n                    \'//section[contains(@class,"mls-l-module--stats-comparison")\'\n                    \' and contains(@class,"mls-l-module--general")\'\n                    \' and not(contains(@style,"display: none"))]\')))\n\n\n            js_scroll_into_view(driver, general_cont)\n            general_cards = scrape_cards(general_cont)\n\n            for it in general_cards:\n                shooting_stats.append({\n                    \'stat_name\': it[\'stat\'],\n                    \'home_value\': it[\'first\'],\n                    \'away_value\': it[\'second\']\n                })\n        except Exception as e:\n            print(f"Error occurred while scraping general stats: {e}")\n\n        try:\n            clubs_wrap = wait.until(\n                EC.visibility_of_element_located((\n                    By.XPATH,\n               ...

# %%
wait = WebDriverWait(driver, 6, poll_frequency=0.2)


for link in links:
    if (link is None or (isinstance(link, float) and math.isnan(link))
            or str(link).strip() == '' or str(link).strip().lower() == 'nan'):
        print(f"[skip] bad link: {link!r}")
        continue

    match_id = link.rstrip('/').split('/')[-1].split('?')[0]

    driver.get(link)

    stats_bttn = wait.until(EC.visibility_of_element_located((By.LINK_TEXT, 'Stats')))


    stats_bttn.click()

    player_rows = []
    gk_rows = []

    try:
        js_scroll_by(driver, -3000)
        time.sleep(2)

        player_btn = wait.until(
            EC.element_to_be_clickable(
                (By.CSS_SELECTOR, '.mls-o-buttons__segment[value="players"]')))
        player_btn.click()

        players_mod = wait.until(
            EC.visibility_of_element_located((
                By.XPATH,
                '//section[contains(@class,"mls-l-module--match-hub-player-stats") and not(contains(@style,"display: none"))]'
            )))

        driver.execute_script("arguments[0].scrollIntoView({block:'center'});",
                            players_mod)

        abbrev_divs = players_mod.find_elements(
            By.CSS_SELECTOR, 'div.mls-c-stats__club-abbreviation')

        player_rows = []
        gk_rows = []

        for i, ab in enumerate(abbrev_divs):
            side = 'home' if i == 0 else 'away'
            club_abbrev = (ab.text or ab.get_attribute('textContent') or '').strip()

            # the table is the FIRST following sibling with class mls-c-stats__table
            tbl = ab.find_element(
                By.XPATH,
                'following-sibling::div[contains(@class,"mls-c-stats__table")][1]'
                '/table[contains(@class,"mls-o-table") and contains(@class,"match-hub-player-stats")]'
            )

            cls = (tbl.get_attribute('class') or '').lower()
            is_gk = 'goalkeeper' in cls

            header_cells = tbl.find_elements(
                By.CSS_SELECTOR,
                'thead .mls-o-table__header-group:not(.mls-o-table__header-group--main) .mls-o-table__header'
            ) or tbl.find_elements(By.CSS_SELECTOR, 'thead .mls-o-table__header')

            headers = [(h.text or h.get_attribute('textContent') or '').strip()
                    for h in header_cells]

            for tr in tbl.find_elements(By.CSS_SELECTOR, 'tbody .mls-o-table__row'):
                cells = tr.find_elements(By.CSS_SELECTOR, '.mls-o-table__cell')
                values = [(c.text or c.get_attribute('textContent') or '').strip()
                        for c in cells]

                if len(values) < len(headers):
                    values += [''] * (len(headers) - len(values))
                elif len(values) > len(headers):
                    values = values[:len(headers)]

                row = dict(zip(headers, values))
                row.update({'match_id': match_id, 'side': side, 'club': club_abbrev})

                if is_gk:
                    gk_rows.append(row)
                else: player_rows.append(row)

                combined_rows = player_rows + gk_rows

    except Exception as e:
        print(f"Error occurred while scraping player stats: {e}")

    player_stats_df = pd.DataFrame(combined_rows)
    player_stats_df.to_csv(
        f"../data/scraping/matches/players/player_stats_{match_id}.csv",
        index=False)
# Out:
# Error occurred while scraping player stats: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=139.0.7258.155); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	GetHandleVerifier [0x0xbea8a3+63283]
# 	GetHandleVerifier [0x0xbea8e4+63348]
# 	(No symbol) [0x0xa23e43]
# 	(No symbol) [0x0xa13790]
# 	(No symbol) [0x0xa31602]
# 	(No symbol) [0x0xa97cdc]
# 	(No symbol) [0x0xab1ff9]
# 	(No symbol) [0x0xa91216]
# 	(No symbol) [0x0xa60855]
# 	(No symbol) [0x0xa616f4]
# 	GetHandleVerifier [0x0xe5bb43+2623955]
# 	GetHandleVerifier [0x0xe56daa+2604090]
# 	GetHandleVerifier [0x0xc1069a+218410]
# 	GetHandleVerifier [0x0xc00ed8+154984]
# 	GetHandleVerifier [0x0xc0742d+180925]
# 	GetHandleVerifier [0x0xbf22b8+94536]
# 	GetHandleVerifier [0x0xbf2442+94930]
# 	GetHandleVerifier [0x0xbdd5ea+9338]
# 	BaseThreadInitThunk [0x0x76775d49+25]
# 	RtlInitializeExceptionChain [0x0x776dd6db+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x776dd661+561]
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[8], line 12
#       8     continue
#      10 match_id = link.rstrip('/').split('/')[-1].split('?')[0]
# ---> 12 driver.get(link)
#      14 stats_bttn = wait.until(EC.visibility_of_element_located((By.LINK_TEXT, 'Stats')))
#      17 stats_bttn.click()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webdriver.py:479, in WebDriver.get(self, url)
#     461 def get(self, url: str) -> None:
#     462     """Navigate the browser to the specified URL in the current window or
#     463     tab.
#     464
#    (...)    477     >>> driver.get("https://example.com")
#     478     """
# --> 479     self.execute(Command.GET, {"url": url})
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webdriver.py:454, in WebDriver.execute(self, driver_command, params)
#     451 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     453 if response:
# --> 454     self.error_handler.check_response(response)
#     455     response["value"] = self._unwrap_value(response.get("value", None))
#     456     return response
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	GetHandleVerifier [0x0xbea8a3+63283]
# 	GetHandleVerifier [0x0xbea8e4+63348]
# 	(No symbol) [0x0xa23ca0]
# 	(No symbol) [0x0xa5fb48]
# 	(No symbol) [0x0xa912d6]
# 	(No symbol) [0x0xa8ceb5]
# 	(No symbol) [0x0xa8c436]
# 	(No symbol) [0x0x9f5755]
# 	(No symbol) [0x0x9f5cae]
# 	(No symbol) [0x0x9f613d]
# 	GetHandleVerifier [0x0xe5bb43+2623955]
# 	GetHandleVerifier [0x0xe56daa+2604090]
# 	GetHandleVerifier [0x0xc1069a+218410]
# 	GetHandleVerifier [0x0xc00ed8+154984]
# 	GetHandleVerifier [0x0xc0742d+180925]
# 	(No symbol) [0x0x9f5420]
# 	(No symbol) [0x0x9f4c36]
# 	GetHandleVerifier [0x0xf968fc+3913612]
# 	BaseThreadInitThunk [0x0x76775d49+25]
# 	RtlInitializeExceptionChain [0x0x776dd6db+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x776dd661+561]
