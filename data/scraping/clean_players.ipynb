# %%
import pandas as pd

# %%
ex = pd.read_csv('./players/CF-Montréal-Aug-31,-2012.csv')

ex.head()
# Out:
#    Unnamed: 0               Name  Age Overall rating     Team & Contract  \
# 0         NaN       T. PerkinsGK   30             65    GK(1)2012 ~ 2016
# 1         NaN  Z. ValentinRBLBCB   20             62   RB(19)2011 ~ 2015
# 2         NaN         N. RivasCB   29             70   RCB(2)2011 ~ 2013
# 3         NaN         A. NestaCB   36           82-2  LCB(14)2012 ~ 2016
# 4         NaN     M. FerrariCBLB   32             73   LB(13)2012 ~ 2013
#
#        ID         Height         Weight   foot  Best overall  ...  \
# 0  152893   188cm / 6'2"  83kg / 183lbs  Right            65  ...
# 1  202076   182cm / 6'0"  70kg / 154lbs  Right            62  ...
# 2  179708  181cm / 5'11"  81kg / 179lbs  Right            70  ...
# 3    1088   187cm / 6'2"  79kg / 174lbs  Right            81  ...
# 4    1539   183cm / 6'0"  77kg / 170lbs  Right            73  ...
#
#   Sliding tackle Total goalkeeping GK Diving  GK Handling  GK Kicking  \
# ...

# %%
print(ex.columns)
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Overall rating', 'Team & Contract', 'ID',
#        'Height', 'Weight', 'foot', 'Best overall', 'Best position', 'Value',
#        'Wage', 'Total attacking', 'Crossing', 'Finishing', 'Heading accuracy',
#        'Short passing', 'Volleys', 'Total skill', 'Dribbling', 'Curve',
#        'FK Accuracy', 'Long passing', 'Ball control', 'Total movement',
#        'Acceleration', 'Sprint speed', 'Agility', 'Reactions', 'Balance',
#        'Total power', 'Shot power', 'Jumping', 'Stamina', 'Long shots',
#        'Total mentality', 'Aggression', 'Interceptions', 'Att. Position',
#        'Vision', 'Penalties', 'Composure', 'Total defending', 'Marking',
#        'Standing tackle', 'Sliding tackle', 'Total goalkeeping', 'GK Diving',
#        'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes',
#        'Unnamed: 53', 'date', 'team'],
#       dtype='object')

# %%
ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 56 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         0 non-null      float64
#  1   Name               29 non-null     object
#  2   Age                29 non-null     int64
#  3   Overall rating     29 non-null     object
#  4   Team & Contract    29 non-null     object
#  5   ID                 29 non-null     int64
#  6   Height             29 non-null     object
#  7   Weight             29 non-null     object
#  8   foot               29 non-null     object
#  9   Best overall       29 non-null     int64
#  10  Best position      29 non-null     object
#  11  Value              29 non-null     object
#  12  Wage               29 non-null     object
#  13  Total attacking    29 non-null     int64
#  14  Crossing           29 non-null     int64
#  15  Finishing          29 non-null     object
# ...

# %%
#remove unnamed columns
ex = ex.loc[:, ~ex.columns.str.contains('^Unnamed')]

## make ID index
ex = ex.set_index('ID')

## split Team and contract into position, jersey_num, contract start and end date
