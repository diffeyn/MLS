# %%
import pandas as pd
import glob
import os

# %%
df = pd.read_csv('G:/My Drive/GitHubProjects/MLS/data/scraping/matches/stats/stats_miavsorl-03-02-2024.csv')

# %%
df
# Out:
#       category           stat_name  home_value  away_value   tip_id  \
# 0     shooting        Possession %        47.2        52.8      NaN
# 1     shooting               Shots        11.0         9.0      NaN
# 2     shooting       Shots on Goal         6.0         3.0      NaN
# 3     shooting       Blocked Shots         1.0         2.0      NaN
# 4     shooting        Total Passes       452.0       514.0      NaN
# 5     shooting  Passing Accuracy %        85.6        88.9      NaN
# 6     shooting             Corners         1.0         5.0      NaN
# 7     shooting       Total Crosses         2.0        18.0      NaN
# 8     shooting            Offsides         3.0         1.0      NaN
# 9     shooting    Aerial Duels Won         1.0         4.0      NaN
# 10    shooting      Expected Goals         2.8         0.8      NaN
# 11    shooting    Goalkeeper Saves         3.0         0.0      NaN
# 12    shooting          Clearances        11.0        11.0      NaN
# 13    shooting               Fouls        18.0        12.0      NaN
# 14    shooting        Yellow Cards         3.0         1.0      NaN
# 15    shooting           Red Cards         0.0         0.0      NaN
# 16    shooting           Overall %        85.6        88.9      NaN
# 17    shooting    Open Play Pass %        86.1        88.2      NaN
# 18    shooting   Set Piece Cross %         0.0        33.3      NaN
# 19    shooting   Open Play Cross %         0.0        22.2      NaN
# 20    shooting               Goals         5.0         0.0      NaN
# 21    shooting           On Target         6.0         3.0      NaN
# 22    shooting          Off Target         6.0         9.0      NaN
# 23    shooting             Blocked         1.0         2.0      NaN
# 24    shooting      Goals Conceded         0.0         5.0      NaN
# 25    shooting       Shots Against        11.0         9.0      NaN
# 26    shooting        Clean Sheets         0.0         0.0      NaN
# 27    shooting         XG Conceded         0.8         2.8      NaN
# 28    shooting       Interceptions         1.0         0.0      NaN
# 29    shooting               Goals         5.0         0.0      NaN
# 30    shooting           On Target         6.0         3.0      NaN
# 31    shooting          Off Target         3.0         4.0      NaN
# 32    shooting             Blocked         1.0         2.0      NaN
# 33     passing           Overall %        85.6        88.9      NaN
# 34     passing    Open Play Pass %        86.1        88.2      NaN
# 35     passing   Set Piece Cross %         0.0        33.3      NaN
# 36     passing   Open Play Cross %         0.0        22.2      NaN
# 37  possession                 NaN         NaN         NaN    bar_0
# 38  possession                 NaN         NaN         NaN    bar_1
# 39  possession                 NaN         NaN         NaN    bar_2
# 40  possession                 NaN         NaN         NaN    bar_3
# 41  possession                 NaN         NaN         NaN    bar_4
# 42  possession                 NaN         NaN         NaN    bar_5
# 43  possession                 NaN         NaN         NaN    bar_6
# 44  possession                 NaN         NaN         NaN    bar_7
# 45  possession                 NaN         NaN         NaN    bar_8
# 46  possession                 NaN         NaN         NaN  bar_2_0
# 47  possession                 NaN         NaN         NaN  bar_2_1
# 48  possession                 NaN         NaN         NaN  bar_2_2
# 49  possession                 NaN         NaN         NaN  bar_2_3
# 50  possession                 NaN         NaN         NaN  bar_2_4
# 51  possession                 NaN         NaN         NaN  bar_2_5
# 52  possession                 NaN         NaN         NaN  bar_2_6
# 53  possession                 NaN         NaN         NaN  bar_2_7
# 54  possession                 NaN         NaN         NaN  bar_2_8
# 55          xg       Total Team XG         2.8         0.8      NaN
# 56          xg               Shots        11.0         9.0      NaN
# 57          xg     Shots On Target         6.0         3.0      NaN
#
#             home_possession         home_advantage          away_possession  \
# 0                       NaN                    NaN                      NaN
# 1                       NaN                    NaN                      NaN
# 2                       NaN                    NaN                      NaN
# 3                       NaN                    NaN                      NaN
# 4                       NaN                    NaN                      NaN
# 5                       NaN                    NaN                      NaN
# 6                       NaN                    NaN                      NaN
# 7                       NaN                    NaN                      NaN
# 8                       NaN                    NaN                      NaN
# 9                       NaN                    NaN                      NaN
# 10                      NaN                    NaN                      NaN
# 11                      NaN                    NaN                      NaN
# 12                      NaN                    NaN                      NaN
# 13                      NaN                    NaN                      NaN
# 14                      NaN                    NaN                      NaN
# 15                      NaN                    NaN                      NaN
# 16                      NaN                    NaN                      NaN
# 17                      NaN                    NaN                      NaN
# 18                      NaN                    NaN                      NaN
# 19                      NaN                    NaN                      NaN
# 20                      NaN                    NaN                      NaN
# 21                      NaN                    NaN                      NaN
# 22                      NaN                    NaN                      NaN
# 23                      NaN                    NaN                      NaN
# 24                      NaN                    NaN                      NaN
# 25                      NaN                    NaN                      NaN
# 26                      NaN                    NaN                      NaN
# 27                      NaN                    NaN                      NaN
# 28                      NaN                    NaN                      NaN
# 29                      NaN                    NaN                      NaN
# 30                      NaN                    NaN                      NaN
# 31                      NaN                    NaN                      NaN
# 32                      NaN                    NaN                      NaN
# 33                      NaN                    NaN                      NaN
# 34                      NaN                    NaN                      NaN
# 35                      NaN                    NaN                      NaN
# 36                      NaN                    NaN                      NaN
# 37  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 38  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 39  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 40  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 41  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 42  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 43  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 44  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 45  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 46  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 47  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 48  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 49  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 50  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 51  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 52  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 53  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 54  Home Possession: 51.23%  Home Advantage: 2.46%  Away Possession: 48.77%
# 55                      NaN                    NaN                      NaN
# 56                      NaN                    NaN                      NaN
# 57                      NaN                    NaN                      NaN
#
#          away_advantage
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# 37  Away Advantage: N/A
# 38  Away Advantage: N/A
# 39  Away Advantage: N/A
# 40  Away Advantage: N/A
# 41  Away Advantage: N/A
# 42  Away Advantage: N/A
# 43  Away Advantage: N/A
# 44  Away Advantage: N/A
# 45  Away Advantage: N/A
# 46  Away Advantage: N/A
# 47  Away Advantage: N/A
# 48  Away Advantage: N/A
# 49  Away Advantage: N/A
# 50  Away Advantage: N/A
# 51  Away Advantage: N/A
# 52  Away Advantage: N/A
# 53  Away Advantage: N/A
# 54  Away Advantage: N/A
# 55                  NaN
# 56                  NaN
# 57                  NaN

# %%
df = df.drop(columns=['home_advantage', 'away_advantage'])

# %%
##combine first and second column into one column

df['stat'] = df['category'].astype(str) + '_' + df['stat_name'].astype(str)

# %%
df = df.drop(columns=['category', 'stat_name'])
df = df[['stat', 'home_value', 'away_value', 'tip_id' , 'home_possession', 'away_possession']]

# %%
df
# Out:
#                            stat  home_value  away_value   tip_id  \
# 0         shooting_Possession %        47.2        52.8      NaN
# 1                shooting_Shots        11.0         9.0      NaN
# 2        shooting_Shots on Goal         6.0         3.0      NaN
# 3        shooting_Blocked Shots         1.0         2.0      NaN
# 4         shooting_Total Passes       452.0       514.0      NaN
# 5   shooting_Passing Accuracy %        85.6        88.9      NaN
# 6              shooting_Corners         1.0         5.0      NaN
# 7        shooting_Total Crosses         2.0        18.0      NaN
# 8             shooting_Offsides         3.0         1.0      NaN
# 9     shooting_Aerial Duels Won         1.0         4.0      NaN
# 10      shooting_Expected Goals         2.8         0.8      NaN
# 11    shooting_Goalkeeper Saves         3.0         0.0      NaN
# 12          shooting_Clearances        11.0        11.0      NaN
# 13               shooting_Fouls        18.0        12.0      NaN
# 14        shooting_Yellow Cards         3.0         1.0      NaN
# 15           shooting_Red Cards         0.0         0.0      NaN
# 16           shooting_Overall %        85.6        88.9      NaN
# 17    shooting_Open Play Pass %        86.1        88.2      NaN
# 18   shooting_Set Piece Cross %         0.0        33.3      NaN
# 19   shooting_Open Play Cross %         0.0        22.2      NaN
# 20               shooting_Goals         5.0         0.0      NaN
# 21           shooting_On Target         6.0         3.0      NaN
# 22          shooting_Off Target         6.0         9.0      NaN
# 23             shooting_Blocked         1.0         2.0      NaN
# 24      shooting_Goals Conceded         0.0         5.0      NaN
# 25       shooting_Shots Against        11.0         9.0      NaN
# 26        shooting_Clean Sheets         0.0         0.0      NaN
# 27         shooting_XG Conceded         0.8         2.8      NaN
# 28       shooting_Interceptions         1.0         0.0      NaN
# 29               shooting_Goals         5.0         0.0      NaN
# 30           shooting_On Target         6.0         3.0      NaN
# 31          shooting_Off Target         3.0         4.0      NaN
# 32             shooting_Blocked         1.0         2.0      NaN
# 33            passing_Overall %        85.6        88.9      NaN
# 34     passing_Open Play Pass %        86.1        88.2      NaN
# 35    passing_Set Piece Cross %         0.0        33.3      NaN
# 36    passing_Open Play Cross %         0.0        22.2      NaN
# 37               possession_nan         NaN         NaN    bar_0
# 38               possession_nan         NaN         NaN    bar_1
# 39               possession_nan         NaN         NaN    bar_2
# 40               possession_nan         NaN         NaN    bar_3
# 41               possession_nan         NaN         NaN    bar_4
# 42               possession_nan         NaN         NaN    bar_5
# 43               possession_nan         NaN         NaN    bar_6
# 44               possession_nan         NaN         NaN    bar_7
# 45               possession_nan         NaN         NaN    bar_8
# 46               possession_nan         NaN         NaN  bar_2_0
# 47               possession_nan         NaN         NaN  bar_2_1
# 48               possession_nan         NaN         NaN  bar_2_2
# 49               possession_nan         NaN         NaN  bar_2_3
# 50               possession_nan         NaN         NaN  bar_2_4
# 51               possession_nan         NaN         NaN  bar_2_5
# 52               possession_nan         NaN         NaN  bar_2_6
# 53               possession_nan         NaN         NaN  bar_2_7
# 54               possession_nan         NaN         NaN  bar_2_8
# 55             xg_Total Team XG         2.8         0.8      NaN
# 56                     xg_Shots        11.0         9.0      NaN
# 57           xg_Shots On Target         6.0         3.0      NaN
#
#             home_possession          away_possession
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
# 5                       NaN                      NaN
# 6                       NaN                      NaN
# 7                       NaN                      NaN
# 8                       NaN                      NaN
# 9                       NaN                      NaN
# 10                      NaN                      NaN
# 11                      NaN                      NaN
# 12                      NaN                      NaN
# 13                      NaN                      NaN
# 14                      NaN                      NaN
# 15                      NaN                      NaN
# 16                      NaN                      NaN
# 17                      NaN                      NaN
# 18                      NaN                      NaN
# 19                      NaN                      NaN
# 20                      NaN                      NaN
# 21                      NaN                      NaN
# 22                      NaN                      NaN
# 23                      NaN                      NaN
# 24                      NaN                      NaN
# 25                      NaN                      NaN
# 26                      NaN                      NaN
# 27                      NaN                      NaN
# 28                      NaN                      NaN
# 29                      NaN                      NaN
# 30                      NaN                      NaN
# 31                      NaN                      NaN
# 32                      NaN                      NaN
# 33                      NaN                      NaN
# 34                      NaN                      NaN
# 35                      NaN                      NaN
# 36                      NaN                      NaN
# 37  Home Possession: 51.23%  Away Possession: 48.77%
# 38  Home Possession: 51.23%  Away Possession: 48.77%
# 39  Home Possession: 51.23%  Away Possession: 48.77%
# 40  Home Possession: 51.23%  Away Possession: 48.77%
# 41  Home Possession: 51.23%  Away Possession: 48.77%
# 42  Home Possession: 51.23%  Away Possession: 48.77%
# 43  Home Possession: 51.23%  Away Possession: 48.77%
# 44  Home Possession: 51.23%  Away Possession: 48.77%
# 45  Home Possession: 51.23%  Away Possession: 48.77%
# 46  Home Possession: 51.23%  Away Possession: 48.77%
# 47  Home Possession: 51.23%  Away Possession: 48.77%
# 48  Home Possession: 51.23%  Away Possession: 48.77%
# 49  Home Possession: 51.23%  Away Possession: 48.77%
# 50  Home Possession: 51.23%  Away Possession: 48.77%
# 51  Home Possession: 51.23%  Away Possession: 48.77%
# 52  Home Possession: 51.23%  Away Possession: 48.77%
# 53  Home Possession: 51.23%  Away Possession: 48.77%
# 54  Home Possession: 51.23%  Away Possession: 48.77%
# 55                      NaN                      NaN
# 56                      NaN                      NaN
# 57                      NaN                      NaN

# %%
## rename bars to every 5 minutes

bar_dict = {
    '0-5': 'bar_0',
    '6-10': 'bar_1',
    '11-15': 'bar_2',
    '16-20': 'bar_3',
    '21-25': 'bar_4',
    '26-30': 'bar_5',
    '31-35': 'bar_6',
    '36-40': 'bar_7',
    '41-45': 'bar_8',
    '46-50': 'bar_2_0',
    '51-55': 'bar_2_1',
    '56-60': 'bar_2_2',
    '61-65': 'bar_2_3',
    '66-70': 'bar_2_4',
    '71-75': 'bar_2_5',
    '76-80': 'bar_2_6',
    '81-85': 'bar_2_7',
    '86-90': 'bar_2_8',
}

bar_dict_switched = {v: k for k, v in bar_dict.items()}

df['tip_id'] = df['tip_id'].astype(str).str.strip() 

df['tip_id'] = df['tip_id'].replace(bar_dict_switched)

# %%
df
# Out:
#                            stat  home_value  away_value tip_id  \
# 0         shooting_Possession %        47.2        52.8    nan
# 1                shooting_Shots        11.0         9.0    nan
# 2        shooting_Shots on Goal         6.0         3.0    nan
# 3        shooting_Blocked Shots         1.0         2.0    nan
# 4         shooting_Total Passes       452.0       514.0    nan
# 5   shooting_Passing Accuracy %        85.6        88.9    nan
# 6              shooting_Corners         1.0         5.0    nan
# 7        shooting_Total Crosses         2.0        18.0    nan
# 8             shooting_Offsides         3.0         1.0    nan
# 9     shooting_Aerial Duels Won         1.0         4.0    nan
# 10      shooting_Expected Goals         2.8         0.8    nan
# 11    shooting_Goalkeeper Saves         3.0         0.0    nan
# 12          shooting_Clearances        11.0        11.0    nan
# 13               shooting_Fouls        18.0        12.0    nan
# 14        shooting_Yellow Cards         3.0         1.0    nan
# 15           shooting_Red Cards         0.0         0.0    nan
# 16           shooting_Overall %        85.6        88.9    nan
# 17    shooting_Open Play Pass %        86.1        88.2    nan
# 18   shooting_Set Piece Cross %         0.0        33.3    nan
# 19   shooting_Open Play Cross %         0.0        22.2    nan
# 20               shooting_Goals         5.0         0.0    nan
# 21           shooting_On Target         6.0         3.0    nan
# 22          shooting_Off Target         6.0         9.0    nan
# 23             shooting_Blocked         1.0         2.0    nan
# 24      shooting_Goals Conceded         0.0         5.0    nan
# 25       shooting_Shots Against        11.0         9.0    nan
# 26        shooting_Clean Sheets         0.0         0.0    nan
# 27         shooting_XG Conceded         0.8         2.8    nan
# 28       shooting_Interceptions         1.0         0.0    nan
# 29               shooting_Goals         5.0         0.0    nan
# 30           shooting_On Target         6.0         3.0    nan
# 31          shooting_Off Target         3.0         4.0    nan
# 32             shooting_Blocked         1.0         2.0    nan
# 33            passing_Overall %        85.6        88.9    nan
# 34     passing_Open Play Pass %        86.1        88.2    nan
# 35    passing_Set Piece Cross %         0.0        33.3    nan
# 36    passing_Open Play Cross %         0.0        22.2    nan
# 37               possession_nan         NaN         NaN    0-5
# 38               possession_nan         NaN         NaN   6-10
# 39               possession_nan         NaN         NaN  11-15
# 40               possession_nan         NaN         NaN  16-20
# 41               possession_nan         NaN         NaN  21-25
# 42               possession_nan         NaN         NaN  26-30
# 43               possession_nan         NaN         NaN  31-35
# 44               possession_nan         NaN         NaN  36-40
# 45               possession_nan         NaN         NaN  41-45
# 46               possession_nan         NaN         NaN  46-50
# 47               possession_nan         NaN         NaN  51-55
# 48               possession_nan         NaN         NaN  56-60
# 49               possession_nan         NaN         NaN  61-65
# 50               possession_nan         NaN         NaN  66-70
# 51               possession_nan         NaN         NaN  71-75
# 52               possession_nan         NaN         NaN  76-80
# 53               possession_nan         NaN         NaN  81-85
# 54               possession_nan         NaN         NaN  86-90
# 55             xg_Total Team XG         2.8         0.8    nan
# 56                     xg_Shots        11.0         9.0    nan
# 57           xg_Shots On Target         6.0         3.0    nan
#
#             home_possession          away_possession
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
# 5                       NaN                      NaN
# 6                       NaN                      NaN
# 7                       NaN                      NaN
# 8                       NaN                      NaN
# 9                       NaN                      NaN
# 10                      NaN                      NaN
# 11                      NaN                      NaN
# 12                      NaN                      NaN
# 13                      NaN                      NaN
# 14                      NaN                      NaN
# 15                      NaN                      NaN
# 16                      NaN                      NaN
# 17                      NaN                      NaN
# 18                      NaN                      NaN
# 19                      NaN                      NaN
# 20                      NaN                      NaN
# 21                      NaN                      NaN
# 22                      NaN                      NaN
# 23                      NaN                      NaN
# 24                      NaN                      NaN
# 25                      NaN                      NaN
# 26                      NaN                      NaN
# 27                      NaN                      NaN
# 28                      NaN                      NaN
# 29                      NaN                      NaN
# 30                      NaN                      NaN
# 31                      NaN                      NaN
# 32                      NaN                      NaN
# 33                      NaN                      NaN
# 34                      NaN                      NaN
# 35                      NaN                      NaN
# 36                      NaN                      NaN
# 37  Home Possession: 51.23%  Away Possession: 48.77%
# 38  Home Possession: 51.23%  Away Possession: 48.77%
# 39  Home Possession: 51.23%  Away Possession: 48.77%
# 40  Home Possession: 51.23%  Away Possession: 48.77%
# 41  Home Possession: 51.23%  Away Possession: 48.77%
# 42  Home Possession: 51.23%  Away Possession: 48.77%
# 43  Home Possession: 51.23%  Away Possession: 48.77%
# 44  Home Possession: 51.23%  Away Possession: 48.77%
# 45  Home Possession: 51.23%  Away Possession: 48.77%
# 46  Home Possession: 51.23%  Away Possession: 48.77%
# 47  Home Possession: 51.23%  Away Possession: 48.77%
# 48  Home Possession: 51.23%  Away Possession: 48.77%
# 49  Home Possession: 51.23%  Away Possession: 48.77%
# 50  Home Possession: 51.23%  Away Possession: 48.77%
# 51  Home Possession: 51.23%  Away Possession: 48.77%
# 52  Home Possession: 51.23%  Away Possession: 48.77%
# 53  Home Possession: 51.23%  Away Possession: 48.77%
# 54  Home Possession: 51.23%  Away Possession: 48.77%
# 55                      NaN                      NaN
# 56                      NaN                      NaN
# 57                      NaN                      NaN

# %%
mask = df["tip_id"].astype(str).str.match(r"^\d{1,2}-\d{1,2}$", na=False)

h_pct = df.loc[mask, "home_possession"].astype(str).str.extract(r"(\d+(?:\.\d+)?)")[0].astype(float)
a_pct = df.loc[mask, "away_possession"].astype(str).str.extract(r"(\d+(?:\.\d+)?)")[0].astype(float)

df.loc[mask, "home_value"] = h_pct.values
df.loc[mask, "away_value"] = a_pct.values

df.loc[mask, "stat"] = "possession_" + df.loc[mask, "tip_id"].str.replace("-", "_", regex=False)

# %%
df  = df.drop(columns=['tip_id', 'home_possession', 'away_possession'])
df
# Out:
#                            stat  home_value  away_value
# 0         shooting_Possession %       47.20       52.80
# 1                shooting_Shots       11.00        9.00
# 2        shooting_Shots on Goal        6.00        3.00
# 3        shooting_Blocked Shots        1.00        2.00
# 4         shooting_Total Passes      452.00      514.00
# 5   shooting_Passing Accuracy %       85.60       88.90
# 6              shooting_Corners        1.00        5.00
# 7        shooting_Total Crosses        2.00       18.00
# 8             shooting_Offsides        3.00        1.00
# 9     shooting_Aerial Duels Won        1.00        4.00
# 10      shooting_Expected Goals        2.80        0.80
# 11    shooting_Goalkeeper Saves        3.00        0.00
# 12          shooting_Clearances       11.00       11.00
# 13               shooting_Fouls       18.00       12.00
# 14        shooting_Yellow Cards        3.00        1.00
# 15           shooting_Red Cards        0.00        0.00
# 16           shooting_Overall %       85.60       88.90
# 17    shooting_Open Play Pass %       86.10       88.20
# 18   shooting_Set Piece Cross %        0.00       33.30
# 19   shooting_Open Play Cross %        0.00       22.20
# 20               shooting_Goals        5.00        0.00
# 21           shooting_On Target        6.00        3.00
# 22          shooting_Off Target        6.00        9.00
# 23             shooting_Blocked        1.00        2.00
# 24      shooting_Goals Conceded        0.00        5.00
# 25       shooting_Shots Against       11.00        9.00
# 26        shooting_Clean Sheets        0.00        0.00
# 27         shooting_XG Conceded        0.80        2.80
# 28       shooting_Interceptions        1.00        0.00
# 29               shooting_Goals        5.00        0.00
# 30           shooting_On Target        6.00        3.00
# 31          shooting_Off Target        3.00        4.00
# 32             shooting_Blocked        1.00        2.00
# 33            passing_Overall %       85.60       88.90
# 34     passing_Open Play Pass %       86.10       88.20
# 35    passing_Set Piece Cross %        0.00       33.30
# 36    passing_Open Play Cross %        0.00       22.20
# 37               possession_0_5       51.23       48.77
# 38              possession_6_10       51.23       48.77
# 39             possession_11_15       51.23       48.77
# 40             possession_16_20       51.23       48.77
# 41             possession_21_25       51.23       48.77
# 42             possession_26_30       51.23       48.77
# 43             possession_31_35       51.23       48.77
# 44             possession_36_40       51.23       48.77
# 45             possession_41_45       51.23       48.77
# 46             possession_46_50       51.23       48.77
# 47             possession_51_55       51.23       48.77
# 48             possession_56_60       51.23       48.77
# 49             possession_61_65       51.23       48.77
# 50             possession_66_70       51.23       48.77
# 51             possession_71_75       51.23       48.77
# 52             possession_76_80       51.23       48.77
# 53             possession_81_85       51.23       48.77
# 54             possession_86_90       51.23       48.77
# 55             xg_Total Team XG        2.80        0.80
# 56                     xg_Shots       11.00        9.00
# 57           xg_Shots On Target        6.00        3.00

# %%
### exract team names and date from filename

filename = 'G:/My Drive/GitHubProjects/MLS/data/scraping/matches/stats/stats_miavsorl-03-02-2024.csv'

base = os.path.basename(filename)

name, ext = os.path.splitext(base)
name = name.replace('stats_', '')
teams = name.split('-')[0]
date = name.split('-')[1:4]

teams
date

## split teams into home and away

home_team = teams.split('vs')[0]
away_team = teams.split('vs')[1]

date = '-'.join(date)
date
# Out:
# '03-02-2024'

# %%
def extract_team_and_date(filename):
    base = os.path.basename(filename)
    name, ext = os.path.splitext(base)
    name = name.replace('stats_', '')
    teams = name.split('-')[0]
    date = name.split('-')[1:4]
    home_team = teams.split('vs')[0]
    away_team = teams.split('vs')[1]
    date = '-'.join(date)
    return home_team, away_team, date

# %%
def clean_teams(df):
    df = df.copy()
    df = df.drop(columns=['home_advantage', 'away_advantage'])
    df['stat'] = df['category'].astype(str) + '_' + df['stat_name'].astype(str)
    df = df.drop(columns=['category', 'stat_name'])
    df['tip_id'] = df['tip_id'].astype(str).str.strip() 
    df['tip_id'] = df['tip_id'].replace(bar_dict_switched)
    mask = df["tip_id"].astype(str).str.match(r"^\d{1,2}-\d{1,2}$", na=False)
    h_pct = df.loc[mask, "home_possession"].astype(str).str.extract(r"(\d+(?:\.\d+)?)")[0].astype(float)
    a_pct = df.loc[mask, "away_possession"].astype(str).str.extract(r"(\d+(?:\.\d+)?)")[0].astype(float)
    df.loc[mask, "home_value"] = h_pct.values 
    df.loc[mask, "away_value"] = a_pct.values
    df.loc[mask, "stat"] = "possession_" + df.loc[mask, "tip_id"].str.replace("-", "_", regex=False)
    df = df.drop(columns=['tip_id', 'home_possession', 'away_possession'])
    df = df[['stat', 'home_value', 'away_value']]
    return df

# %%
folder = glob.glob('G:/My Drive/GitHubProjects/MLS/data/scraping/matches/stats/*.csv')

for file in folder:
    df = pd.read_csv(file)
    try:
        cleaned_df = clean_teams(df)
    except Exception as e:
        print(f"Error cleaning {file}: {e}")
        continue
    filename = os.path.basename(file)
    cleaned_df.to_csv(
        f"G:/My Drive/GitHubProjects/MLS/data/data_clean/matches/raw/stats/cleaned_{filename}",
        index=False)
# Out:
# Error cleaning G:/My Drive/GitHubProjects/MLS/data/scraping/matches/stats\stats_chivshou-04-06-2024.csv: "['home_advantage', 'away_advantage'] not found in axis"
