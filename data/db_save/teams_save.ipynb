# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv('G:/My Drive/GitHubProjects/MLS/data/data_clean/teams/teams_2025-07-17.csv')

# %%
df
# Out:
#     Unnamed: 0               team_name   lineup    style  overall_score  \
# 0       112893             Inter Miami    4-4-2  Holding             73
# 1       111144     Seattle Sounders FC  3-4-2-1      NaN             71
# 2       112996          Los Angeles FC    4-3-3  Holding             71
# 3          697               LA Galaxy  4-2-3-1     Wide             71
# 4       113018       St. Louis CITY SC  3-4-2-1      NaN             70
# 5       114640            Charlotte FC    4-3-3  Holding             70
# 6       112885          Atlanta United  4-2-3-1     Wide             70
# 7       113149           FC Cincinnati  3-4-2-1      NaN             70
# 8       111140        Portland Timbers  4-2-3-1     Wide             69
# 9       111928    San Jose Earthquakes    3-5-2      NaN             69
# 10         687           Columbus Crew  3-4-2-1      NaN             69
# 11         689      New York Red Bulls  4-2-3-1     Wide             69
# ...

# %%
### rename unnamed column to team_id
df = df.rename(columns={'Unnamed: 0': 'team_id'})
df
# Out:
#     team_id               team_name   lineup    style  overall_score  attack  \
# 0    112893             Inter Miami    4-4-2  Holding             73      84
# 1    111144     Seattle Sounders FC  3-4-2-1      NaN             71      73
# 2    112996          Los Angeles FC    4-3-3  Holding             71      74
# 3       697               LA Galaxy  4-2-3-1     Wide             71      70
# 4    113018       St. Louis CITY SC  3-4-2-1      NaN             70      73
# 5    114640            Charlotte FC    4-3-3  Holding             70      73
# 6    112885          Atlanta United  4-2-3-1     Wide             70      67
# 7    113149           FC Cincinnati  3-4-2-1      NaN             70      71
# 8    111140        Portland Timbers  4-2-3-1     Wide             69      71
# 9    111928    San Jose Earthquakes    3-5-2      NaN             69      74
# 10      687           Columbus Crew  3-4-2-1      NaN             69      64
# ...

# %%
df = df[['team_id', 'team_name']]

teams_dict = {
    'Inter Miami': 'MIA',
    'Seattle Sounders FC': 'SEA',
    'Los Angeles FC': 'LAFC',
    'LA Galaxy': 'LA',
    'St. Louis CITY SC': 'STL',
    'Charlotte FC': 'CLT',
    'Atlanta United': 'ATL',
    'FC Cincinnati': 'CIN',
    'Portland Timbers': 'POR',
    'San Jose Earthquakes': 'SJ',
    'Columbus Crew': 'CLB',
    'New York Red Bulls': 'RBNY',
    'New England Revolution': 'NE',
    'Houston Dynamo': 'HOU',
    'Orlando City SC': 'ORL',
    'Austin FC': 'ATX',
    'Nashville SC': 'NSH',
    'Vancouver Whitecaps FC': 'VAN',
    'Philadelphia Union': 'PHI',
    'Minnesota United FC': 'MIN',
    'Toronto FC': 'TOR',
    'Chicago Fire': 'CHI',
    'FC Dallas': 'DAL',
    'Sporting Kansas City': 'SKC',
    'Real Salt Lake': 'RSL',
    'DC United': 'DC',
    'Colorado Rapids': 'COL',
    'New York City FC': 'NYC',
    'CF Montréal': 'MTL'
}

# %%
df['team_abbr'] = df['team_name'].map(teams_dict)
# Out:
# C:\Users\diffe\AppData\Local\Temp\ipykernel_2012\2601928823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['team_abbr'] = df['team_name'].map(teams_dict)

# %%
df
# Out:
#     team_id               team_name team_abbr
# 0    112893             Inter Miami       MIA
# 1    111144     Seattle Sounders FC       SEA
# 2    112996          Los Angeles FC      LAFC
# 3       697               LA Galaxy        LA
# 4    113018       St. Louis CITY SC       STL
# 5    114640            Charlotte FC       CLT
# 6    112885          Atlanta United       ATL
# 7    113149           FC Cincinnati       CIN
# 8    111140        Portland Timbers       POR
# 9    111928    San Jose Earthquakes        SJ
# 10      687           Columbus Crew       CLB
# 11      689      New York Red Bulls      RBNY
# 12      691  New England Revolution        NE
# 13      698          Houston Dynamo       HOU
# 14   112606         Orlando City SC       ORL
# 15   114161               Austin FC       ATX
# 16   114162            Nashville SC       NSH
# 17   101112  Vancouver Whitecaps FC       VAN
# 18   112134      Philadelphia Union       PHI
# ...

# %%
db_string = 'mysql+mysqldb://root:root@127.0.0.1:2022/MLS'

engine = create_engine(db_string)

# %%
df.to_sql('teams', engine, if_exists='append', index=False)
# Out:
# 29
