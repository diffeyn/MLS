# %%
import pandas as pd
from sqlalchemy import create_engine
import os

db_string = 'mysql+pymysql://root:root@127.0.0.1:2022/MLS'

engine = create_engine(db_string)

# %%
input_folder = 'G:/My Drive/GitHubProjects/MLS/data/data_clean/players'

all_files = [f"{input_folder}/{i}" for i in os.listdir(input_folder) if i.endswith('.csv')]


df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# %%
df.to_csv('all_players_long.csv', index=False)

# %%
df.drop_duplicates(subset=['id'], keep='first', inplace=True)

# %%
df.to_csv('all_players.csv', index=False)

# %%
df = pd.read_csv('all_players.csv')

# %%
## rename id to player_id

df.rename(columns={'id': 'player_id'}, inplace=True)

# %%
df
# Out:
#       player_id        date          name   age  height_cm  weight_kg  \
# 0        254962  2025-07-17  D. Callender  26.0        191         88
# 1        260732  2025-07-17       I. Fray  21.0        183         73
# 2        262339  2025-07-17      G. Luján  23.0        182         82
# 3        267872  2025-07-17      N. Allen  20.0        175         66
# 4        189332  2025-07-17    Jordi Alba  35.0        170         68
# ...         ...         ...           ...   ...        ...        ...
# 3797       1088  2013-11-01      A. Nesta  37.0        187         79
# 3798     212826  2013-07-26      F. Monge  22.0        178         79
# 3799     166314  2012-08-31   E. Sebrango  39.0        183         80
# 3800     208428  2012-08-31      E. James  22.0        173         71
# 3801        560  2012-08-31    B. Corradi  36.0        191         86
#
#              team  contract_start  contract_end position  ...  \
# 0     Inter Miami          2019.0        2025.0       GK  ...
# ...

# %%
##3 keep player_id, name, height, and foot

df = df[['player_id', 'name', 'height_cm', 'foot']]

# %%
df
# Out:
#       player_id          name  height_cm   foot
# 0        254962  D. Callender        191  Right
# 1        260732       I. Fray        183  Right
# 2        262339      G. Luján        182  Right
# 3        267872      N. Allen        175   Left
# 4        189332    Jordi Alba        170   Left
# ...         ...           ...        ...    ...
# 3797       1088      A. Nesta        187  Right
# 3798     212826      F. Monge        178  Right
# 3799     166314   E. Sebrango        183  Right
# 3800     208428      E. James        173   Left
# 3801        560    B. Corradi        191  Right
#
# [3802 rows x 4 columns]

# %%
## save to sql

df.to_sql('players_general', con=engine, if_exists='append', index=False)
# Out:
# 3802
