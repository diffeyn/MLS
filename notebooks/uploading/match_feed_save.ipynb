# %%
import pandas as pd
import glob
import os
from sqlalchemy import create_engine

db_string = 'mysql+pymysql://root:!wMoU9lBdLZWW6Y8@o8ukkP9TliImN.h.filess.io:58202/MLS'


engine = create_engine(db_string)

# %%
df = pd.read_csv('G:/My Drive/GitHubProjects/MLS/data/interim/matches/feed/cleaned_mls_match_feeds3.csv')

df
# Out:
#       match_id        date  feed_id minute           title  \
# 0     bb7391b6  2026-03-08       38    15'     Yellow Card
# 1     bb7391b6  2026-03-08       37    19'   Attempt Saved
# 2     bb7391b6  2026-03-08       36    25'     Yellow Card
# 3     bb7391b6  2026-03-08       35    29'   Attempt Saved
# 4     bb7391b6  2026-03-08       34    29'  Attempt Missed
# ...        ...         ...      ...    ...             ...
# 1562  dee239a9  2026-02-21        5    84'    Substitution
# 1563  dee239a9  2026-02-21        4    86'  Attempt Missed
# 1564  dee239a9  2026-02-21        3    88'   Attempt Saved
# 1565  dee239a9  2026-02-21        2    88'            GOAL
# 1566  dee239a9  2026-02-21        1    90'    Substitution
#
#                                                 comment
# 0     Ender Echenique (FC Cincinnati) is shown the y...
# 1     Attempt blocked. Dániel Sallói's (Toronto FC) ...
# 2     Benjamín Kuscevic (Toronto FC) is shown the ye...
# ...

# %%
df.rename(columns={'minute' : 'event_minute', 'title': 'event_type', 'comment' : 'event_comment'}, inplace=True)

# %%
df
# Out:
#       match_id        date  feed_id event_minute      event_type  \
# 0     bb7391b6  2026-03-08       38          15'     Yellow Card
# 1     bb7391b6  2026-03-08       37          19'   Attempt Saved
# 2     bb7391b6  2026-03-08       36          25'     Yellow Card
# 3     bb7391b6  2026-03-08       35          29'   Attempt Saved
# 4     bb7391b6  2026-03-08       34          29'  Attempt Missed
# ...        ...         ...      ...          ...             ...
# 1562  dee239a9  2026-02-21        5          84'    Substitution
# 1563  dee239a9  2026-02-21        4          86'  Attempt Missed
# 1564  dee239a9  2026-02-21        3          88'   Attempt Saved
# 1565  dee239a9  2026-02-21        2          88'            GOAL
# 1566  dee239a9  2026-02-21        1          90'    Substitution
#
#                                           event_comment
# 0     Ender Echenique (FC Cincinnati) is shown the y...
# 1     Attempt blocked. Dániel Sallói's (Toronto FC) ...
# ...

# %%
df = df.rename(columns={'feed_id' : 'event_id'})

# %%
df
# Out:
#              date  event_id event_minute      event_type  \
# 0      2025-10-18        36        90'+7  Attempt Missed
# 1      2025-10-18        35        90'+7            Foul
# 2      2025-10-18        34        90'+5          Corner
# 3      2025-10-18        33          89'    Substitution
# 4      2025-10-18        32          83'   Attempt Saved
# ...           ...       ...          ...             ...
# 38652  2024-02-21         5          23'   Attempt Saved
# 38653  2024-02-21         4          21'   Attempt Saved
# 38654  2024-02-21         3          20'   Attempt Saved
# 38655  2024-02-21         2          15'            Foul
# 38656  2024-02-21         1           6'  Attempt Missed
#
#                                            event_comment home_team away_team  \
# 0      Attempt missed. Nicolás Romero's (Minnesota Un...        LA       MIN
# 1      Edwin Cerrillo (LA Galaxy) is shown the second...        LA       MIN
# ...

# %%
### organzise columns
df = df[['event_id','match_id', 'event_minute', 'event_type', 'event_comment']]

# %%
df.to_sql('match_events', engine, if_exists='append', index=False)
# Out:
# 1567
