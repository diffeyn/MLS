# %%
import pandas as pd
from sqlalchemy import create_engine
import os

db_string = 'mysql+pymysql://root:!wMoU9lBdLZWW6Y8@o8ukkP9TliImN.h.filess.io:58202/MLS'

engine = create_engine(db_string)

# %%
df = pd.read_csv('G:/My Drive/GitHubProjects/MLS/data/interim//cleaned_master_players_w_team_abbr_post031426.csv')

# %%
df2 = pd.read_csv('G:/My Drive/GitHubProjects/MLS/data/interim/players/cleaned_master_players_w_team_abbr_post031426_2.csv')

# %%
## rename id to player_id

df.rename(columns={'id': 'player_id'}, inplace=True)

# %%
df
# Out:
#       player_id        date          name  age  height_cm  weight_kg  \
# 0        247228  2026-03-10  D. St. Clair   28        191         86
# 1        262339  2026-03-10      G. Lujan   24        182         82
# 2        259298  2026-03-10     M. Falcon   28        179         80
# 3        260732  2026-03-10       I. Fray   22        183         73
# 4        267872  2026-03-10      N. Allen   21        175         66
# ...         ...         ...           ...  ...        ...        ...
# 2135      80612  2026-02-18       P. Soma   19        177         75
# 2136      70074  2026-02-18   K. Sargeant   22        182         73
# 2137      77459  2026-02-18      A. Saidi   17        185         67
# 2138      73870  2026-02-18    D. Vazquez   19        175         65
# 2139     255411  2026-02-18       B. Duke   24        170         66
#
#          team_name  contract_start  contract_end  position  ...  \
# 0      Inter Miami             NaN           NaN       NaN  ...
# ...

# %%
##3 keep player_id, name, height, and foot

df = df[['player_id', 'name', 'height_cm', 'foot']]

# %%
df
# Out:
#       player_id          name  height_cm   foot
# 0        247228  D. St. Clair        191   Left
# 1        262339      G. Lujan        182  Right
# 2        259298     M. Falcon        179  Right
# 3        260732       I. Fray        183  Right
# 4        267872      N. Allen        175   Left
# ...         ...           ...        ...    ...
# 2135      80612       P. Soma        177  Right
# 2136      70074   K. Sargeant        182  Right
# 2137      77459      A. Saidi        185  Right
# 2138      73870    D. Vazquez        175   Left
# 2139     255411       B. Duke        170  Right
#
# [2140 rows x 4 columns]

# %%
### keep only one entry per player_id

df = df.drop_duplicates(subset=['player_id'])

# %%
df
# Out:
#       player_id          name  height_cm   foot
# 0        247228  D. St. Clair        191   Left
# 1        262339      G. Lujan        182  Right
# 2        259298     M. Falcon        179  Right
# 3        260732       I. Fray        183  Right
# 4        267872      N. Allen        175   Left
# ...         ...           ...        ...    ...
# 2080      77459      A. Saidi        185  Right
# 2081      73870    D. Vazquez        175   Left
# 2082     255411       B. Duke        170  Right
# 2083      79998     W. Eisner        183  Right
# 2093     260482      T. Angel        175   Left
#
# [799 rows x 4 columns]

# %%
from sqlalchemy import inspect

inspector = inspect(engine)
print(inspector.get_table_names())  # Lists all tables in the default schema
print(inspector.has_table("players_general"))
# Out:
# ['match_events', 'match_player_stats', 'match_team_stats', 'matches', 'player_finance', 'players_finance', 'players_general', 'players_general_name_stage', 'players_stats', 'roster_snapshots', 'team_roster', 'team_roster_stage', 'team_stats', 'teams']
# True

# %%
from sqlalchemy import Table, MetaData, insert

metadata = MetaData()
metadata.reflect(bind=engine)

# Access any table like a dictionary
players_table = metadata.tables['players_general']

stmt = insert(players_table).prefix_with("IGNORE").values(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 4
#       1 from sqlalchemy import Table, MetaData, insert
#       3 metadata = MetaData()
# ----> 4 metadata.reflect(bind=engine)
#       6 # Access any table like a dictionary
#       7 players_table = metadata.tables['players_general']
#
# File c:\Users\diffe\anaconda3\Lib\site-packages\sqlalchemy\sql\schema.py:5761, in MetaData.reflect(self, bind, schema, views, only, extend_existing, autoload_replace, resolve_fks, **dialect_kwargs)
#    5662 @util.preload_module("sqlalchemy.engine.reflection")
#    5663 def reflect(
#    5664     self,
#    (...)
#    5674     **dialect_kwargs: Any,
#    5675 ) -> None:
#    5676     r"""Load all available table definitions from the database.
#    5677
#    5678     Automatically creates ``Table`` entries in this ``MetaData`` for any
#    (...)
#    5758
#    5759     """
# ...

# %%
## save to sql

df.to_sql('players_general', con=engine, if_exists='append', index=False)
# Out:
# 3911

# %%
old1 = pd.read_csv('G:/My Drive/GitHubProjects/MLS/data/interim/master_players_w_team_abbr.csv')
old2 = pd.read_csv('G:/My Drive/GitHubProjects/MLS/data/interim/master_players_w_team_abbr_post021026.csv')
old3 = pd.read_csv('G:/My Drive/GitHubProjects/MLS/data/interim/cleaned_master_players_w_team_abbr_post031426.csv')

# %%
master = pd.concat([old1, old2, old3], ignore_index=True)

# %%
master
# Out:
#              id        date                name   age  height_cm  weight_kg  \
# 0        238919  2023-01-18         J. Pantemis  25.0        188         79
# 1        255956  2023-01-18         J. Waterman  26.0        185         75
# 2        206485  2023-01-18          R. Camacho  31.0        185         79
# 3        247648  2023-01-18           K. Miller  25.0        183         88
# 4        243574  2023-01-18  Z. Brault-Guillard  23.0        171         65
# ...         ...         ...                 ...   ...        ...        ...
# 1942471   80612  2026-02-18             P. Soma  19.0        177         75
# 1942472   70074  2026-02-18         K. Sargeant  22.0        182         73
# 1942473   77459  2026-02-18            A. Saidi  17.0        185         67
# 1942474   73870  2026-02-18          D. Vazquez  19.0        175         65
# 1942475  255411  2026-02-18             B. Duke  24.0        170         66
#
# ...

# %%
master.to_csv('G:/My Drive/GitHubProjects/MLS/data/interim/cleaned_master_players_w_team_abbr_post031426_2.csv', index=False)

# %%
df2.head()
# Out:
#        id        date                name   age  height_cm  weight_kg  \
# 0  238919  2023-01-18         J. Pantemis  25.0        188         79
# 1  255956  2023-01-18         J. Waterman  26.0        185         75
# 2  206485  2023-01-18          R. Camacho  31.0        185         79
# 3  247648  2023-01-18           K. Miller  25.0        183         88
# 4  243574  2023-01-18  Z. Brault-Guillard  23.0        171         65
#
#      team_name  contract_start  contract_end position  ...  \
# 0  CF Montréal          2018.0        2023.0       GK  ...
# 1  CF Montréal          2020.0        2023.0      RCB  ...
# 2  CF Montréal          2022.0        2023.0       CB  ...
# 3  CF Montréal          2021.0        2023.0      LCB  ...
# 4  CF Montréal          2020.0        2022.0       RM  ...
#
#   defensive_awareness  standing_tackle  sliding_tackle  total_goalkeeping  \
# 0                 8.0             12.0              14                315
# ...

# %%
unique_df = df2.drop_duplicates(subset=['id'], keep='first')

# %%
unique_df
# Out:
#              id        date                name   age  height_cm  weight_kg  \
# 0        238919  2023-01-18         J. Pantemis  25.0        188         79
# 1        255956  2023-01-18         J. Waterman  26.0        185         75
# 2        206485  2023-01-18          R. Camacho  31.0        185         79
# 3        247648  2023-01-18           K. Miller  25.0        183         88
# 4        243574  2023-01-18  Z. Brault-Guillard  23.0        171         65
# ...         ...         ...                 ...   ...        ...        ...
# 1454472   83296  2026-02-05         N. Markovic  20.0        193         93
# 1454715   82879  2026-02-05             C. Flax  21.0        180         68
# 1454716   82889  2026-02-05            K. Acito  21.0        190         84
# 1455539  279938  2026-02-05             S. Jura  19.0        172         69
# 1456205   73878  2026-02-05           C. Cowell  16.0        170         71
#
# ...

# %%
### find ids not in players_general

players_general = pd.read_sql("SELECT * FROM players_general", con=engine)

ids_not_in_general = unique_df[~unique_df['id'].isin(players_general['player_id'])]

ids_not_in_general
# Out:
# Empty DataFrame
# Columns: [id, date, name, age, height_cm, weight_kg, team_name, contract_start, contract_end, position, foot, jersey_num, wage_eur, value_eur, overall_rating, best_overall, best_position, total_attacking, crossing, finishing, heading_accuracy, short_passing, volleys, total_skill, dribbling, curve, fk_accuracy, long_passing, ball_control, total_movement, acceleration, sprint_speed, agility, reactions, balance, total_power, shot_power, jumping, stamina, long_shots, total_mentality, aggression, interceptions, attack_position, vision, penalties, composure, total_defending, defensive_awareness, standing_tackle, sliding_tackle, total_goalkeeping, gk_diving, gk_handling, gk_kicking, gk_positioning, gk_reflexes, team_abbr]
# Index: []
#
# [0 rows x 58 columns]

# %%
master = master[['id', 'name', 'height_cm', 'foot']]

# %%
### find nan values in master

nan_values = master[master.isna().any(axis=1)]

nan_values
# Out:
# Empty DataFrame
# Columns: [id, name, height_cm, foot]
# Index: []

# %%
### fill id 220575 with Victor Pagliari Giro

master.loc[master['id'] == 220575, 'name'] = 'Victor Pagliari Giro'

# %%
### find na values in master

nan_values = master[master.isna().any(axis=1)]

nan_values
# Out:
# Empty DataFrame
# Columns: [id, name, height_cm, foot]
# Index: []

# %%
from sqlalchemy import create_engine, Table, MetaData, insert

# 1. Define your table (must match your DB structure)
metadata = MetaData()
players_table = Table("players_general", metadata, autoload_with=engine) # or define Columns manually

# 2. Convert DataFrame to a list of dicts
data = master.to_dict(orient="records")

# 3. Build and execute the statement
stmt = insert(players_table).prefix_with("IGNORE")

with engine.connect() as conn:
    conn.execute(stmt, data) # Pass data as the second argument
    conn.commit()
# Out:
# C:\Users\diffe\AppData\Local\Temp\ipykernel_16048\753919839.py:14: SAWarning: Column 'players_general.player_id' is marked as a member of the primary key for table 'players_general', but has no Python-side or server-side default generator indicated, nor does it indicate 'autoincrement=True' or 'nullable=True', and no explicit value is passed.  Primary key columns typically may not store NULL.
#   conn.execute(stmt, data) # Pass data as the second argument

# %%
with engine.connect() as conn:
    conn.commit()

# %%
### compare db and master dataframes for ids not in other

mysql_values = set(pd.read_sql("SELECT player_id FROM players_general", engine)["player_id"])
df_values    = set(master["id"])
old_values   = set(df2["id"])

in_mysql_not_df = mysql_values - df_values
in_df_not_mysql = df_values - mysql_values
in_old_not_new = old_values - df_values
in_new_not_old = df_values - old_values
in_sql_not_old = mysql_values - old_values
in_old_not_sql = old_values - mysql_values

# %%
print(f"Original length: {len(master)}")
print(f"Unique length: {len(unique_df)}")
print(f"Length of older master DataFrame: {len(df2)}")
print(f"IDs in MySQL not in DataFrame: {in_mysql_not_df}")
print(f"IDs in DataFrame not in MySQL: {in_df_not_mysql}")
print(f"IDs in older master DataFrame not in new DataFrame: {in_old_not_new}")
print(f"IDs in new DataFrame not in older master DataFrame: {in_new_not_old}") 
print(f"IDs in MySQL not in DataFrame: {in_sql_not_old}")
print(f"IDs in DataFrame not in MySQL: {in_old_not_sql}")
print(f"number of ids in MySQL not in DataFrame: {len(in_mysql_not_df)}")
print(f"number of ids in DataFrame not in MySQL: {len(in_df_not_mysql)}")
print(f"number of ids in older master DataFrame not in new DataFrame: {len(in_old_not_new)}")
print(f"number of ids in new DataFrame not in older master DataFrame: {len(in_new_not_old)}")
print(f"number of ids in MySQL not in DataFrame: {len(in_sql_not_old)}")
print(f"number of ids in old DataFrame not in MySQL: {len(in_old_not_sql)}")
# Out:
# Original length: 1942476
# Unique length: 3853
# Length of older master DataFrame: 1457107
# IDs in MySQL not in DataFrame: {0, 1539, 246660, 200067, 212358, 213896, 234377, 177803, 245900, 155277, 242836, 223638, 177311, 236836, 233765, 225577, 166314, 146475, 208428, 215982, 560, 260656, 216243, 231992, 223800, 224570, 137403, 221884, 213436, 1088, 248389, 208838, 31432, 1099, 138699, 122361, 225486, 232016, 212728, 200787, 116308, 222038, 226266, 163419, 179708, 212826, 237279, 232033, 176993, 226405, 225254, 198760, 192369, 186100, 218868, 176376, 107769, 255740, 242301}
# ...
